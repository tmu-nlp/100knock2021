# %%
import re
class Morph:
    def __init__(self,item):
        self.surface=item[0]
        self.base=item[len(items)-3]
        self.pos=items[1]
        self.pos1=items[2] 
        
class Chunk:
    def __init__(self,idx,dst):
        self.idx = idx     
        self.morphs = []   
        self.dst = dst     
        self.srcs = [] 
    def __str__(self):
        surfs = [morph.surface for morph in self.morphs]
        return "{}\t\tdst: {}\tsrcs: {}".format("".join(surfs),self.dst,self.srcs)
        
with open("ai.ja.txt.parsed","r",encoding="utf-8") as ai:
    result=[]
    sent=[]
    for line in ai:
        line=line.strip()
        items=re.split("[ ,\t]",line)
        if items[0]=="*":
            idx=int(items[1])
            items[2]=items[2].strip("D")
            dst=int(items[2])
            chunk=Chunk(idx,dst)
            sent.append(chunk)
            
        elif items[0]=="EOS":
            if sent:
                result.append(sent)
                sent=[]
            
        else:
            chunk.morphs.append(Morph(items))
            
    for sen in result:
        for chunk in sen:
            if chunk.dst!=-1:
                sen[int(chunk.dst)].srcs.append(chunk.idx)
                
    for sen in result:
        for chunk in sen:
            print(chunk)
        print()
# Out:
# 人工知能		dst: -1	srcs: []
#
# 人工知能		dst: 17	srcs: []
# （じんこうちのう、、		dst: 17	srcs: []
# AI		dst: 3	srcs: []
# 〈エーアイ〉）とは、		dst: 17	srcs: [2]
# 「『計算		dst: 5	srcs: []
# （）』という		dst: 9	srcs: [4]
# 概念と		dst: 9	srcs: []
# 『コンピュータ		dst: 8	srcs: []
# （）』という		dst: 9	srcs: [7]
# 道具を		dst: 10	srcs: [5, 6, 8]
# 用いて		dst: 12	srcs: [9]
# 『知能』を		dst: 12	srcs: []
# 研究する		dst: 13	srcs: [10, 11]
# 計算機科学		dst: 14	srcs: [12]
# （）の		dst: 15	srcs: [13]
# 一分野」を		dst: 16	srcs: [14]
# 指す		dst: 17	srcs: [15]
# 語。		dst: 34	srcs: [0, 1, 3, 16]
# 「言語の		dst: 20	srcs: []
# 理解や		dst: 20	srcs: []
# 推論、		dst: 21	srcs: [18, 19]
# 問題解決などの		dst: 22	srcs: [20]
# 知的行動を		dst: 24	srcs: [21]
# 人間に		dst: 24	srcs: []
# 代わって		dst: 26	srcs: [22, 23]
# コンピューターに		dst: 26	srcs: []
# 行わせる		dst: 27	srcs: [24, 25]
# 技術」、または、		dst: 34	srcs: [26]
# 「計算機		dst: 29	srcs: []
# （コンピュータ）による		dst: 31	srcs: [28]
# 知的な		dst: 31	srcs: []
# 情報処理システムの		dst: 33	srcs: [29, 30]
# 設計や		dst: 33	srcs: []
# 実現に関する		dst: 34	srcs: [31, 32]
# 研究分野」とも		dst: 35	srcs: [17, 27, 33]
# される。		dst: -1	srcs: [34]
#
# 『日本大百科全書(ニッポニカ)』の		dst: 1	srcs: []
# 解説で、		dst: 5	srcs: [0]
# 情報工学者・通信工学者の		dst: 3	srcs: []
# 佐藤理史は		dst: 5	srcs: [2]
# 次のように		dst: 5	srcs: []
# 述べている。		dst: -1	srcs: [1, 3, 4]
#
# 人間の		dst: 1	srcs: []
# 知的能力を		dst: 3	srcs: [0]
# コンピュータ上で		dst: 3	srcs: []
# 実現する、		dst: 5	srcs: [1, 2]
# 様々な		dst: 5	srcs: []
# 技術・ソフトウェア・コンピュータシステム。		dst: 19	srcs: [3, 4]
# 応用例は		dst: 19	srcs: []
# 自然言語処理		dst: 8	srcs: []
# （機械翻訳・かな漢字変換・構文解析等）、		dst: 9	srcs: [7]
# 専門家の		dst: 10	srcs: [8]
# 推論・判断を		dst: 11	srcs: [9]
# 模倣する		dst: 12	srcs: [10]
# エキスパートシステム、		dst: 18	srcs: [11]
# 画像データを		dst: 14	srcs: []
# 解析して		dst: 17	srcs: [13]
# 特定の		dst: 16	srcs: []
# パターンを		dst: 17	srcs: [15]
# 検出・抽出したりする		dst: 18	srcs: [14, 16]
# 画像認識等が		dst: 19	srcs: [12, 17]
# ある。		dst: 23	srcs: [5, 6, 18]
# 1956年に		dst: 23	srcs: []
# ダートマス会議で		dst: 23	srcs: []
# ジョン・マッカーシーにより		dst: 23	srcs: []
# 命名された。		dst: 35	srcs: [19, 20, 21, 22]
# 現在では、		dst: 35	srcs: []
# 記号処理を		dst: 26	srcs: []
# 用いた		dst: 27	srcs: [25]
# 知能の		dst: 28	srcs: [26]
# 記述を		dst: 30	srcs: [27]
# 主体と		dst: 30	srcs: []
# する		dst: 32	srcs: [28, 29]
# 情報処理や		dst: 32	srcs: []
# 研究での		dst: 33	srcs: [30, 31]
# アプローチという		dst: 34	srcs: [32]
# 意味あいでも		dst: 35	srcs: [33]
# 使われている。		dst: 43	srcs: [23, 24, 34]
# 家庭用電気機械器具の		dst: 37	srcs: []
# 制御システムや		dst: 39	srcs: [36]
# ゲームソフトの		dst: 39	srcs: []
# 思考ルーチンも		dst: 41	srcs: [37, 38]
# こう		dst: 41	srcs: []
# 呼ばれる		dst: 42	srcs: [39, 40]
# ことも		dst: 43	srcs: [41]
# ある。		dst: -1	srcs: [35, 42]
#
# プログラミング言語による		dst: 1	srcs: []
# 「」という		dst: 2	srcs: [0]
# カウンセラーを		dst: 3	srcs: [1]
# 模倣した		dst: 4	srcs: [2]
# プログラム		dst: 8	srcs: [3]
# （人工無脳）が		dst: 8	srcs: []
# しばしば		dst: 8	srcs: []
# 引き合いに		dst: 8	srcs: []
# 出されるが、		dst: 27	srcs: [4, 5, 6, 7]
# 計算機に		dst: 13	srcs: []
# 人間の		dst: 11	srcs: []
# 専門家の		dst: 12	srcs: [10]
# 役割を		dst: 13	srcs: [11]
# させようという		dst: 14	srcs: [9, 12]
# 「エキスパートシステム」と		dst: 15	srcs: [13]
# 呼ばれる		dst: 16	srcs: [14]
# 研究・情報処理システムの		dst: 17	srcs: [15]
# 実現は、		dst: 27	srcs: [16]
# 人間が		dst: 20	srcs: []
# 暗黙に		dst: 20	srcs: []
# 持つ		dst: 21	srcs: [18, 19]
# 常識の		dst: 22	srcs: [20]
# 記述が		dst: 24	srcs: [21]
# 問題と		dst: 24	srcs: []
# なり、		dst: 27	srcs: [22, 23]
# 実用への		dst: 26	srcs: []
# 利用が		dst: 27	srcs: [25]
# 困難視されている。		dst: 42	srcs: [8, 17, 24, 26]
# 人工的な		dst: 29	srcs: []
# 知能の		dst: 30	srcs: [28]
# 実現への		dst: 31	srcs: [29]
# アプローチとしては、		dst: 35	srcs: [30]
# 「ファジィ理論」や		dst: 33	srcs: []
# 「ニューラルネットワーク」などのような		dst: 34	srcs: [32]
# アプローチも		dst: 35	srcs: [33]
# 知られているが、		dst: 42	srcs: [31, 34]
# 従来の		dst: 37	srcs: []
# 人工知能である		dst: 38	srcs: [36]
# (GoodOldFashionedAI)との		dst: 39	srcs: [37]
# 差は		dst: 42	srcs: [38]
# 記述の		dst: 41	srcs: []
# 記号的明示性に		dst: 42	srcs: [40]
# ある。		dst: 46	srcs: [27, 35, 39, 41]
# その後		dst: 46	srcs: []
# 「サポートベクターマシン」が		dst: 46	srcs: []
# 注目を		dst: 46	srcs: []
# 集めた。		dst: 55	srcs: [42, 43, 44, 45]
# また、		dst: 55	srcs: []
# 自らの		dst: 49	srcs: []
# 経験を		dst: 52	srcs: [48]
# 元に		dst: 52	srcs: []
# 学習を		dst: 52	srcs: []
# 行う		dst: 53	srcs: [49, 50, 51]
# 強化学習という		dst: 54	srcs: [52]
# 手法も		dst: 55	srcs: [53]
# ある。		dst: 71	srcs: [46, 47, 54]
# 「この		dst: 57	srcs: []
# 宇宙において、		dst: 67	srcs: [56]
# 知性とは		dst: 61	srcs: []
# 最も		dst: 60	srcs: []
# 強力な		dst: 61	srcs: [59]
# 形質である		dst: 62	srcs: [58, 60]
# （レイ・カーツワイル）」という		dst: 63	srcs: [61]
# 言葉通り、		dst: 67	srcs: [62]
# 知性を		dst: 66	srcs: []
# 機械的に		dst: 66	srcs: []
# 表現し		dst: 67	srcs: [64, 65]
# 実装するという		dst: 68	srcs: [57, 63, 66]
# ことは		dst: 71	srcs: [67]
# 極めて		dst: 70	srcs: []
# 重要な		dst: 71	srcs: [69]
# 作業である。		dst: -1	srcs: [55, 68, 70]
#
# 2006年の		dst: 1	srcs: []
# ディープラーニング		dst: 3	srcs: [0]
# （深層学習）の		dst: 3	srcs: []
# 登場と		dst: 7	srcs: [1, 2]
# 2010年代		dst: 5	srcs: []
# 以降の		dst: 6	srcs: [4]
# ビッグデータの		dst: 7	srcs: [5]
# 登場により、		dst: 13	srcs: [3, 6]
# 一過性の		dst: 9	srcs: []
# 流行を		dst: 10	srcs: [8]
# 超えて		dst: 12	srcs: [9]
# 社会に		dst: 12	srcs: []
# 浸透して		dst: 13	srcs: [10, 11]
# 行った。		dst: 36	srcs: [7, 12]
# 2016年から		dst: 15	srcs: []
# 2017年にかけて、		dst: 17	srcs: [14]
# ディープラーニングを		dst: 17	srcs: []
# 導入した		dst: 18	srcs: [15, 16]
# AIが		dst: 19	srcs: [17]
# 完全情報ゲームである		dst: 20	srcs: [18]
# 囲碁などの		dst: 21	srcs: [19]
# トップ棋士、		dst: 26	srcs: [20]
# さらに		dst: 23	srcs: []
# 不完全情報ゲームである		dst: 24	srcs: [22]
# ポーカーの		dst: 25	srcs: [23]
# 世界トップクラスの		dst: 26	srcs: [24]
# プレイヤーも		dst: 27	srcs: [21, 25]
# 破り、		dst: 36	srcs: [26]
# 麻雀では		dst: 36	srcs: []
# 「MicrosoftSuphx(SuperPhoenix)」が		dst: 33	srcs: []
# AIとして		dst: 33	srcs: []
# 初めて		dst: 33	srcs: []
# 十段に		dst: 33	srcs: []
# 到達するなど、		dst: 36	srcs: [29, 30, 31, 32]
# 時代の		dst: 35	srcs: []
# 最先端技術と		dst: 36	srcs: [34]
# なった。		dst: -1	srcs: [13, 27, 28, 33, 35]
#
# 第２次人工知能ブームでの		dst: 1	srcs: []
# 人工知能は		dst: 3	srcs: [0]
# 機械学習と		dst: 3	srcs: []
# 呼ばれ、		dst: 6	srcs: [1, 2]
# 以下のような		dst: 5	srcs: []
# ものが		dst: 6	srcs: [4]
# ある。		dst: -1	srcs: [3, 5]
#
# 一方、		dst: 26	srcs: []
# 計算知能		dst: 2	srcs: []
# （CI）は		dst: 12	srcs: [1]
# 開発や		dst: 4	srcs: []
# 学習を		dst: 5	srcs: [3]
# 繰り返す		dst: 6	srcs: [4]
# ことを		dst: 8	srcs: [5]
# 基本と		dst: 8	srcs: []
# している		dst: 9	srcs: [6, 7]
# （例えば、		dst: 12	srcs: [8]
# パラメータ調整、		dst: 12	srcs: []
# コネクショニズムの		dst: 12	srcs: []
# システム）。		dst: 21	srcs: [2, 9, 10, 11]
# 学習は		dst: 16	srcs: []
# 経験に		dst: 15	srcs: []
# 基づく		dst: 16	srcs: [14]
# 手法であり、		dst: 21	srcs: [13, 15]
# 非記号的AI、		dst: 18	srcs: []
# 美しくない		dst: 20	srcs: [17]
# AI、		dst: 20	srcs: []
# ソフトコンピューティングと		dst: 21	srcs: [18, 19]
# 関係している。		dst: 26	srcs: [12, 16, 20]
# その		dst: 23	srcs: []
# 手法としては、		dst: 26	srcs: [22]
# 以下の		dst: 25	srcs: []
# ものが		dst: 26	srcs: [24]
# ある。		dst: -1	srcs: [0, 21, 23, 25]
#
# これらを		dst: 1	srcs: []
# 統合した		dst: 2	srcs: [0]
# 知的システムを		dst: 3	srcs: [1]
# 作る		dst: 4	srcs: [2]
# 試みも		dst: 5	srcs: [3]
# なされている。		dst: 13	srcs: [4]
# ACT-Rでは、		dst: 13	srcs: []
# エキスパートの		dst: 8	srcs: []
# 推論ルールを、		dst: 13	srcs: [7]
# 統計的学習を		dst: 13	srcs: []
# 元に		dst: 13	srcs: []
# ニューラルネットワークや		dst: 12	srcs: []
# 生成規則を通して		dst: 13	srcs: [11]
# 生成する。		dst: -1	srcs: [5, 6, 8, 9, 10, 12]
#
# 第3次人工知能ブームでは、		dst: 15	srcs: []
# ディープラーニングが		dst: 2	srcs: []
# 画像認識、		dst: 3	srcs: [1]
# テキスト解析、		dst: 4	srcs: [2]
# 音声認識など		dst: 6	srcs: [3]
# 様々な		dst: 6	srcs: []
# 領域で		dst: 9	srcs: [4, 5]
# 第2次人工知能ブームの		dst: 8	srcs: []
# 人工知能を		dst: 9	srcs: [7]
# 上回る		dst: 10	srcs: [6, 8]
# 精度を		dst: 11	srcs: [9]
# 出しており、		dst: 15	srcs: [10]
# ディープラーニングの		dst: 13	srcs: []
# 研究が		dst: 15	srcs: [12]
# 盛んに		dst: 15	srcs: []
# 行われている。		dst: 26	srcs: [0, 11, 13, 14]
# 最近では、		dst: 26	srcs: []
# DQN、		dst: 18	srcs: []
# CNN、		dst: 19	srcs: [17]
# RNN、		dst: 20	srcs: [18]
# GANと		dst: 22	srcs: [19]
# 様々な		dst: 22	srcs: []
# ディープラーニングの		dst: 23	srcs: [20, 21]
# 派生が		dst: 24	srcs: [22]
# でて		dst: 26	srcs: [23]
# 各分野で		dst: 26	srcs: []
# 活躍している。		dst: 42	srcs: [15, 16, 24, 25]
# 特に、		dst: 42	srcs: []
# GAN		dst: 29	srcs: []
# （敵対的生成ネットワーク）は、		dst: 42	srcs: [28]
# ディープラーニングが		dst: 35	srcs: []
# 認識や		dst: 32	srcs: []
# 予測などの		dst: 33	srcs: [31]
# 分野で		dst: 35	srcs: [32]
# 成果を		dst: 35	srcs: []
# だしている		dst: 36	srcs: [30, 33, 34]
# ことに		dst: 37	srcs: [35]
# 加えて、		dst: 42	srcs: [36]
# 画像の		dst: 39	srcs: []
# 生成技術において		dst: 42	srcs: [38]
# 大きな		dst: 41	srcs: []
# 進化を		dst: 42	srcs: [40]
# 見せている。		dst: 55	srcs: [26, 27, 29, 37, 39, 41]
# 森正弥は		dst: 50	srcs: []
# これらの		dst: 45	srcs: []
# 成果を		dst: 46	srcs: [44]
# 背景に、		dst: 50	srcs: [45]
# 従来の		dst: 48	srcs: []
# 人工知能の		dst: 49	srcs: [47]
# 応用分野が		dst: 50	srcs: [48]
# 広がっており、		dst: 55	srcs: [43, 46, 49]
# CreativeAIという		dst: 52	srcs: []
# コンテンツ生成を		dst: 53	srcs: [51]
# 行っていく		dst: 54	srcs: [52]
# 応用も		dst: 55	srcs: [53]
# 始まっていると		dst: 56	srcs: [42, 50, 54]
# 指摘している。		dst: -1	srcs: [55]
#
# AIの		dst: 1	srcs: []
# 構築が		dst: 2	srcs: [0]
# 長い間		dst: 3	srcs: [1]
# 試みられてきているが、		dst: 9	srcs: [2]
# シンボルグラウンディング問題と		dst: 5	srcs: []
# フレーム問題の		dst: 6	srcs: [4]
# 解決が		dst: 9	srcs: [5]
# 大きな		dst: 8	srcs: []
# 壁と		dst: 9	srcs: [7]
# なってきた。		dst: -1	srcs: [3, 6, 8]
#
# 17世紀		dst: 1	srcs: []
# 初め、		dst: 9	srcs: [0]
# ルネ・デカルトは、		dst: 9	srcs: []
# 動物の		dst: 4	srcs: []
# 身体が		dst: 8	srcs: [3]
# ただの		dst: 7	srcs: []
# 複雑な		dst: 7	srcs: []
# 機械であると		dst: 8	srcs: [5, 6]
# 提唱した		dst: 9	srcs: [4, 7]
# （機械論）。		dst: 14	srcs: [1, 2, 8]
# ブレーズ・パスカルは		dst: 14	srcs: []
# 1642年、		dst: 14	srcs: []
# 最初の		dst: 13	srcs: []
# 機械式計算機を		dst: 14	srcs: [12]
# 製作した。		dst: 20	srcs: [9, 10, 11, 13]
# チャールズ・バベッジと		dst: 16	srcs: []
# エイダ・ラブレスは		dst: 20	srcs: [15]
# プログラム可能な		dst: 18	srcs: []
# 機械式計算機の		dst: 19	srcs: [17]
# 開発を		dst: 20	srcs: [18]
# 行った。		dst: -1	srcs: [14, 16, 19]
#
# バートランド・ラッセルと		dst: 1	srcs: []
# アルフレッド・ノース・ホワイトヘッドは		dst: 6	srcs: [0]
# 『数学原理』を		dst: 3	srcs: []
# 出版し、		dst: 6	srcs: [2]
# 形式論理に		dst: 6	srcs: []
# 革命を		dst: 6	srcs: []
# もたらした。		dst: 19	srcs: [1, 3, 4, 5]
# ウォーレン・マカロックと		dst: 8	srcs: []
# ウォルター・ピッツは		dst: 16	srcs: [7]
# 「神経活動に		dst: 10	srcs: []
# 内在する		dst: 11	srcs: [9]
# アイデアの		dst: 12	srcs: [10]
# 論理計算」と		dst: 13	srcs: [11]
# 題する		dst: 14	srcs: [12]
# 論文を		dst: 16	srcs: [13]
# 1943年に		dst: 16	srcs: []
# 発表し、		dst: 19	srcs: [8, 14, 15]
# ニューラルネットワークの		dst: 18	srcs: []
# 基礎を		dst: 19	srcs: [17]
# 築いた。		dst: -1	srcs: [6, 16, 18]
#
# 1950年代に		dst: 1	srcs: []
# なると		dst: 5	srcs: [0]
# AIに関して		dst: 5	srcs: []
# 活発な		dst: 4	srcs: []
# 成果が		dst: 5	srcs: [3]
# 出始めた。		dst: 12	srcs: [1, 2, 4]
# ジョン・マッカーシーは		dst: 12	srcs: []
# AIに関する		dst: 8	srcs: []
# 最初の		dst: 9	srcs: [7]
# 会議で		dst: 12	srcs: [8]
# 「人工知能」という		dst: 11	srcs: []
# 用語を		dst: 12	srcs: [10]
# 作り出した。		dst: 15	srcs: [5, 6, 9, 11]
# 彼はまた		dst: 15	srcs: []
# プログラミング言語を		dst: 15	srcs: []
# 開発した。		dst: 22	srcs: [12, 13, 14]
# 知的ふるまいに関する		dst: 17	srcs: []
# テストを		dst: 18	srcs: [16]
# 可能にする		dst: 19	srcs: [17]
# 方法として、		dst: 22	srcs: [18]
# アラン・チューリングは		dst: 22	srcs: []
# 「チューリングテスト」を		dst: 22	srcs: []
# 導入した。		dst: 24	srcs: [15, 19, 20, 21]
# ジョセフ・ワイゼンバウムはを		dst: 24	srcs: []
# 構築した。		dst: 28	srcs: [22, 23]
# これは		dst: 28	srcs: []
# 来談者中心療法を		dst: 27	srcs: []
# 行う		dst: 28	srcs: [26]
# おしゃべりロボットである。		dst: -1	srcs: [24, 25, 27]
#
# 1956年に		dst: 1	srcs: []
# 行われた、		dst: 3	srcs: [0]
# ダートマス会議開催の		dst: 3	srcs: []
# 提案書において、		dst: 7	srcs: [1, 2]
# 人類史上、		dst: 5	srcs: []
# 用語として		dst: 7	srcs: [4]
# 初めて		dst: 7	srcs: []
# 使用され、		dst: 10	srcs: [3, 5, 6]
# 新たな		dst: 9	srcs: []
# 分野として		dst: 10	srcs: [8]
# 創立された。		dst: -1	srcs: [7, 9]
#
# 1960年代と		dst: 1	srcs: []
# 1970年代の		dst: 2	srcs: [0]
# 間に、		dst: 8	srcs: [1]
# ジョエル・モーゼスは		dst: 8	srcs: []
# プログラム中で		dst: 8	srcs: []
# 積分問題での		dst: 6	srcs: []
# 記号的推論の		dst: 7	srcs: [5]
# パワーを		dst: 8	srcs: [6]
# 示した。		dst: 19	srcs: [2, 3, 4, 7]
# マービン・ミンスキーと		dst: 10	srcs: []
# シーモア・パパートは		dst: 16	srcs: [9]
# 『パーセプトロン』を		dst: 12	srcs: []
# 出版して		dst: 16	srcs: [11]
# 単純な		dst: 14	srcs: []
# ニューラルネットの		dst: 15	srcs: [13]
# 限界を		dst: 16	srcs: [14]
# 示し、		dst: 19	srcs: [10, 12, 15]
# アラン・カルメラウアーは		dst: 19	srcs: []
# プログラミング言語を		dst: 19	srcs: []
# 開発した。		dst: 28	srcs: [8, 16, 17, 18]
# テッド・ショートリッフェは		dst: 24	srcs: []
# 医学的診断と		dst: 22	srcs: []
# 療法における		dst: 23	srcs: [21]
# ルールベースシステムを		dst: 24	srcs: [22]
# 構築し、		dst: 28	srcs: [20, 23]
# 知識表現と		dst: 26	srcs: []
# 推論の		dst: 27	srcs: [25]
# パワーを		dst: 28	srcs: [26]
# 示した。		dst: 34	srcs: [19, 24, 27]
# これは、		dst: 34	srcs: []
# 最初の		dst: 31	srcs: []
# エキスパートシステムと		dst: 32	srcs: [30]
# 呼ばれる		dst: 33	srcs: [31]
# ことも		dst: 34	srcs: [32]
# ある。		dst: 36	srcs: [28, 29, 33]
# ハンス・モラベックは、		dst: 36	srcs: []
# 障害物の		dst: -1	srcs: [34, 35]
#
# ある		dst: 1	srcs: []
# コースを		dst: 3	srcs: [0]
# 自律的に		dst: 3	srcs: []
# 走行する		dst: 4	srcs: [1, 2]
# 最初の		dst: 5	srcs: [3]
# コンピューター制御の		dst: 6	srcs: [4]
# 乗り物を		dst: 7	srcs: [5]
# 開発した。		dst: -1	srcs: [6]
#
# 1980年代に、		dst: 4	srcs: []
# ニューラルネットワークは		dst: 4	srcs: []
# バックプロパゲーションアルゴリズムによって		dst: 4	srcs: []
# 広く		dst: 4	srcs: []
# 使われるようになった。		dst: -1	srcs: [0, 1, 2, 3]
#
# また、		dst: 9	srcs: []
# この		dst: 2	srcs: []
# 時代に		dst: 9	srcs: [1]
# ロドニー・ブルックスが、		dst: 9	srcs: []
# 知能には		dst: 9	srcs: []
# 身体が		dst: 6	srcs: []
# 必須との		dst: 7	srcs: [5]
# 学説		dst: 8	srcs: [6]
# （身体性）を		dst: 9	srcs: [7]
# 提唱した。		dst: -1	srcs: [0, 2, 3, 4, 8]
#
# 1990年代は		dst: 7	srcs: []
# AIの		dst: 2	srcs: []
# 多くの		dst: 3	srcs: [1]
# 分野で		dst: 7	srcs: [2]
# 様々な		dst: 5	srcs: []
# アプリケーションが		dst: 7	srcs: [4]
# 成果を		dst: 7	srcs: []
# 上げた。		dst: 30	srcs: [0, 3, 5, 6]
# 特に、		dst: 10	srcs: []
# ボードゲームでは		dst: 10	srcs: []
# 目覚ましく、		dst: 30	srcs: [8, 9]
# 1992年に		dst: 16	srcs: []
# IBMは		dst: 16	srcs: []
# 世界チャンピオンに		dst: 14	srcs: []
# 匹敵する		dst: 15	srcs: [13]
# バックギャモン専用コンピュータ・TDギャモンを		dst: 16	srcs: [14]
# 開発し、		dst: 30	srcs: [11, 12, 15]
# IBMの		dst: 18	srcs: []
# チェス専用コンピュータ・ディープ・ブルーは、		dst: 30	srcs: [17]
# 1997年		dst: 20	srcs: []
# 5月に		dst: 22	srcs: [19]
# ガルリ・カスパロフを		dst: 22	srcs: []
# 打ち負かし、		dst: 30	srcs: [20, 21]
# 同年		dst: 24	srcs: []
# 8月には		dst: 30	srcs: [23]
# オセロで		dst: 30	srcs: []
# 日本電気の		dst: 27	srcs: []
# オセロ専用コンピュータ・ロジステロに		dst: 30	srcs: [26]
# 世界チャンピオンの		dst: 29	srcs: []
# 村上健が		dst: 30	srcs: [28]
# 敗れた。		dst: 47	srcs: [7, 10, 16, 18, 22, 24, 25, 27, 29]
# 国防高等研究計画局は、		dst: 47	srcs: []
# 最初の		dst: 33	srcs: []
# 湾岸戦争において		dst: 35	srcs: [32]
# ユニットを		dst: 35	srcs: []
# スケジューリングするのに		dst: 37	srcs: [33, 34]
# AIを		dst: 37	srcs: []
# 使い、		dst: 45	srcs: [35, 36]
# これによって		dst: 39	srcs: []
# 省かれた		dst: 40	srcs: [38]
# コストが		dst: 45	srcs: [39]
# 1950年代以来の		dst: 42	srcs: []
# AI研究への		dst: 43	srcs: [41]
# 政府の		dst: 44	srcs: [42]
# 投資全額を		dst: 45	srcs: [43]
# 上回った		dst: 46	srcs: [37, 40, 44]
# ことを		dst: 47	srcs: [45]
# 明らかにした。		dst: 57	srcs: [30, 31, 46]
# 日本では		dst: 54	srcs: []
# 甘利俊一（日本学士院会員）らが		dst: 51	srcs: []
# 精力的に		dst: 51	srcs: []
# 啓蒙し、		dst: 54	srcs: [49, 50]
# 優秀な		dst: 53	srcs: []
# 成果も		dst: 54	srcs: [52]
# 発生したが、		dst: 57	srcs: [48, 51, 53]
# 論理の		dst: 56	srcs: []
# ブラックボックス性が		dst: 57	srcs: [55]
# 指摘された。		dst: -1	srcs: [47, 54, 56]
#
# 1998年には		dst: 4	srcs: []
# 非構造化データ形式の		dst: 2	srcs: []
# 国際規格である		dst: 3	srcs: [1]
# XMLが		dst: 4	srcs: [2]
# 提唱されたが、		dst: 15	srcs: [0, 3]
# ここから		dst: 11	srcs: []
# Web上の		dst: 7	srcs: []
# 非構造化データに対して、		dst: 11	srcs: [6]
# アプリケーション別に		dst: 9	srcs: []
# 適した		dst: 10	srcs: [8]
# 意味付けを		dst: 11	srcs: [9]
# 適用し、		dst: 13	srcs: [5, 7, 10]
# 処理を		dst: 13	srcs: []
# 行わせる		dst: 14	srcs: [11, 12]
# 試みが		dst: 15	srcs: [13]
# 開始された。		dst: 24	srcs: [4, 14]
# 同年に、		dst: 22	srcs: []
# W		dst: 18	srcs: []
# 3Cの		dst: 19	srcs: [17]
# ティム・バーナーズ＝リーにより、		dst: 22	srcs: [18]
# Webに		dst: 22	srcs: []
# 知的処理を		dst: 22	srcs: []
# 行わせる		dst: 23	srcs: [16, 19, 20, 21]
# セマンティック・ウェブが		dst: 24	srcs: [22]
# 提唱された。		dst: 37	srcs: [15, 23]
# この		dst: 26	srcs: []
# 技術は		dst: 37	srcs: [25]
# Web上の		dst: 28	srcs: []
# データに		dst: 30	srcs: [27]
# 意味を		dst: 30	srcs: []
# 付加して、		dst: 33	srcs: [28, 29]
# コンピュータに		dst: 33	srcs: []
# 知的処理を		dst: 33	srcs: []
# 行わせる		dst: 34	srcs: [30, 31, 32]
# 方法を		dst: 36	srcs: [33]
# 国際的に		dst: 36	srcs: []
# 規格化する		dst: 37	srcs: [34, 35]
# ものである。		dst: 52	srcs: [24, 26, 36]
# この		dst: 39	srcs: []
# 規格には		dst: 45	srcs: [38]
# 知識工学における		dst: 41	srcs: []
# オントロジーを		dst: 42	srcs: [40]
# 表現する		dst: 43	srcs: [41]
# データ形式の		dst: 44	srcs: [42]
# OWLも		dst: 45	srcs: [43]
# 含まれている		dst: 46	srcs: [39, 44]
# ことから、		dst: 52	srcs: [45]
# かつて		dst: 48	srcs: []
# 流行した		dst: 49	srcs: [47]
# エキスパートシステムの		dst: 50	srcs: [48]
# 亜種である		dst: 51	srcs: [49]
# ことが		dst: 52	srcs: [50]
# 分かる。		dst: 65	srcs: [37, 46, 51]
# 2000年代		dst: 54	srcs: []
# 前半に		dst: 56	srcs: [53]
# 規格化が		dst: 56	srcs: []
# 完了しているが、		dst: 65	srcs: [54, 55]
# Web開発者にとっては		dst: 65	srcs: []
# 開発工数に		dst: 59	srcs: []
# 見合うだけの		dst: 60	srcs: [58]
# メリットが		dst: 61	srcs: [59]
# 見出せなかった		dst: 62	srcs: [60]
# ことから、		dst: 65	srcs: [61]
# 現在も		dst: 65	srcs: []
# 普及は		dst: 65	srcs: []
# していない。		dst: -1	srcs: [52, 56, 57, 62, 63, 64]
#
# 日本においては		dst: 5	srcs: []
# エキスパートシステムの		dst: 2	srcs: []
# 流行の		dst: 3	srcs: [1]
# 後に		dst: 5	srcs: [2]
# ニューロファジィが		dst: 5	srcs: []
# 流行した。		dst: 23	srcs: [0, 3, 4]
# しかし、		dst: 23	srcs: []
# 研究が		dst: 8	srcs: []
# 進むにつれて		dst: 14	srcs: [7]
# 計算リソースや		dst: 10	srcs: []
# データ量の		dst: 11	srcs: [9]
# 不足，		dst: 12	srcs: [10]
# シンボルグラウンディング問題，		dst: 13	srcs: [11]
# フレーム問題に		dst: 14	srcs: [12]
# 直面し、		dst: 17	srcs: [8, 13]
# 産業の		dst: 16	srcs: []
# 在り方を		dst: 17	srcs: [15]
# 激変させるような		dst: 18	srcs: [14, 16]
# AIに		dst: 19	srcs: [17]
# 至る		dst: 20	srcs: [18]
# ことは		dst: 21	srcs: [19]
# 無く、		dst: 23	srcs: [20]
# ブームは		dst: 23	srcs: []
# 終焉した。		dst: -1	srcs: [5, 6, 21, 22]
#
# 1980年代に		dst: 1	srcs: []
# 入って、		dst: 15	srcs: [0]
# 大企業の		dst: 3	srcs: []
# 研究所を		dst: 4	srcs: [2]
# 中心に、		dst: 15	srcs: [3]
# 知識工学に		dst: 6	srcs: []
# 基づく		dst: 7	srcs: [5]
# エキスパートシステムが		dst: 9	srcs: [6]
# 多数		dst: 9	srcs: []
# 提案されるようになり、		dst: 15	srcs: [7, 8]
# エキスパートシステムを		dst: 12	srcs: []
# 専門と		dst: 12	srcs: []
# する		dst: 13	srcs: [10, 11]
# AIベンチャーも		dst: 15	srcs: [12]
# 次々と		dst: 15	srcs: []
# 立ち上がった。		dst: 22	srcs: [1, 4, 9, 13, 14]
# その		dst: 17	srcs: []
# 流行から		dst: 18	srcs: [16]
# 生まれた		dst: 19	srcs: [17]
# 究極の		dst: 20	srcs: [18]
# プロジェクトとして		dst: 22	srcs: [19]
# 第五世代コンピュータが		dst: 22	srcs: []
# 挙げられる。		dst: -1	srcs: [15, 20, 21]
#
# 1982年から		dst: 1	srcs: []
# 1992年まで		dst: 29	srcs: [0]
# 日本は		dst: 29	srcs: []
# 国家プロジェクトとして		dst: 5	srcs: []
# 570億円を		dst: 5	srcs: []
# 費やして		dst: 8	srcs: [3, 4]
# 第五世代コンピュータの		dst: 7	srcs: []
# 研究を		dst: 8	srcs: [6]
# 進めるも、		dst: 29	srcs: [5, 7]
# 採用した		dst: 10	srcs: []
# 知識工学的手法では		dst: 14	srcs: [9]
# 膨大な		dst: 12	srcs: []
# ルールの		dst: 13	srcs: [11]
# 手入力が		dst: 14	srcs: [12]
# 必要で、		dst: 25	srcs: [10, 13]
# 専門家間で		dst: 18	srcs: []
# 専門知識の		dst: 17	srcs: []
# 解釈が		dst: 18	srcs: [16]
# 異なる		dst: 19	srcs: [15, 17]
# 場合には		dst: 25	srcs: [18]
# 統一した		dst: 21	srcs: []
# ルール化が		dst: 22	srcs: [20]
# 行えない		dst: 23	srcs: [21]
# 等の		dst: 24	srcs: [22]
# 問題も		dst: 25	srcs: [23]
# あり、		dst: 29	srcs: [14, 19, 24]
# 実用的な		dst: 27	srcs: []
# エキスパートシステムの		dst: 28	srcs: [26]
# 実現には		dst: 29	srcs: [27]
# 至らなかった。		dst: 47	srcs: [1, 2, 8, 25, 28]
# 実現した		dst: 31	srcs: []
# 成果物は		dst: 42	srcs: [30]
# Prologの		dst: 33	srcs: []
# 命令を		dst: 38	srcs: [32]
# 直接		dst: 38	srcs: []
# CPUの		dst: 36	srcs: []
# ハードウェアの		dst: 37	srcs: [35]
# 機構で		dst: 38	srcs: [36]
# 解釈して		dst: 40	srcs: [33, 34, 37]
# 高速に		dst: 40	srcs: []
# 実行する、		dst: 42	srcs: [38, 39]
# 並列型の		dst: 42	srcs: []
# Prolog専用機であるが、		dst: 47	srcs: [31, 40, 41]
# 商業的な		dst: 44	srcs: []
# 意味で		dst: 47	srcs: [43]
# 応用先が		dst: 47	srcs: []
# 全く		dst: 47	srcs: []
# 見つからなかった。		dst: -1	srcs: [29, 42, 44, 45, 46]
#
# 1980年代		dst: 1	srcs: []
# 後半から		dst: 3	srcs: [0]
# 1990年代		dst: 3	srcs: []
# 中頃にかけて、		dst: 7	srcs: [1, 2]
# 従来から		dst: 7	srcs: []
# 電子制御の		dst: 6	srcs: []
# 手法として		dst: 7	srcs: [5]
# 用いられてきた		dst: 8	srcs: [3, 4, 6]
# ON/OFF制御，		dst: 9	srcs: [7]
# PID制御，		dst: 10	srcs: [8]
# 現代制御の		dst: 11	srcs: [9]
# 問題を		dst: 12	srcs: [10]
# 克服する		dst: 13	srcs: [11]
# ため、		dst: 34	srcs: [12]
# 知的制御が		dst: 16	srcs: []
# 盛んに		dst: 16	srcs: []
# 研究され、		dst: 34	srcs: [14, 15]
# 知識工学的な		dst: 18	srcs: []
# ルールを		dst: 19	srcs: [17]
# 用いる		dst: 20	srcs: [18]
# ファジィ制御，		dst: 25	srcs: [19]
# データの		dst: 22	srcs: []
# 特徴を		dst: 23	srcs: [21]
# 学習して		dst: 24	srcs: [22]
# 分類する		dst: 25	srcs: [23]
# ニューラルネットワーク，		dst: 29	srcs: [20, 24]
# その		dst: 27	srcs: []
# 2つを		dst: 28	srcs: [26]
# 融合した		dst: 29	srcs: [27]
# ニューロファジィという		dst: 30	srcs: [25, 28]
# 手法が		dst: 34	srcs: [29]
# 日本を		dst: 32	srcs: []
# 中心に		dst: 34	srcs: [31]
# ブームを		dst: 34	srcs: []
# 迎えた。		dst: 51	srcs: [13, 16, 30, 32, 33]
# バブル期の		dst: 36	srcs: []
# 高級路線に		dst: 37	srcs: [35]
# 合わせて、		dst: 43	srcs: [36]
# 白物家電製品でも		dst: 43	srcs: []
# センサの		dst: 40	srcs: []
# 個数と		dst: 41	srcs: [39]
# 種類を		dst: 43	srcs: [40]
# 大幅に		dst: 43	srcs: []
# 増やし、		dst: 48	srcs: [37, 38, 41, 42]
# 多様な		dst: 45	srcs: []
# データを		dst: 46	srcs: [44]
# 元に		dst: 48	srcs: [45]
# 運転を		dst: 48	srcs: []
# 最適化する		dst: 49	srcs: [43, 46, 47]
# モデルが		dst: 51	srcs: [48]
# 多数		dst: 51	srcs: []
# 発売され始めた。		dst: -1	srcs: [34, 49, 50]
#
# ファジィについては、		dst: 14	srcs: []
# 2018年までに		dst: 6	srcs: []
# 日本が		dst: 6	srcs: []
# 世界の		dst: 4	srcs: []
# 1/5の		dst: 5	srcs: [3]
# 特許を		dst: 6	srcs: [4]
# 取得している		dst: 7	srcs: [1, 2, 5]
# 事から、		dst: 12	srcs: [6]
# 日本で		dst: 12	srcs: []
# 特に		dst: 12	srcs: []
# 大きな		dst: 11	srcs: []
# ブームと		dst: 12	srcs: [10]
# なっていた		dst: 13	srcs: [7, 8, 9, 11]
# ことが		dst: 14	srcs: [12]
# 分かっている。		dst: 28	srcs: [0, 13]
# 現在の		dst: 16	srcs: []
# 白物家電では		dst: 22	srcs: [15]
# この		dst: 18	srcs: []
# 当時より		dst: 20	srcs: [17]
# 更に		dst: 20	srcs: []
# 発展した		dst: 21	srcs: [18, 19]
# 制御技術が		dst: 22	srcs: [20]
# 用いられているが、		dst: 28	srcs: [16, 21]
# 既に		dst: 26	srcs: []
# 当たり前の		dst: 25	srcs: []
# ものに		dst: 26	srcs: [24]
# なり、		dst: 28	srcs: [23, 25]
# 利用者には		dst: 28	srcs: []
# 意識されなくなっている。		dst: 43	srcs: [14, 22, 26, 27]
# ニューロファジィが		dst: 31	srcs: []
# ブームに		dst: 31	srcs: []
# なった		dst: 32	srcs: [29, 30]
# 1990年代には		dst: 43	srcs: [31]
# 未だ		dst: 43	srcs: []
# ビッグデータという		dst: 35	srcs: []
# 概念は		dst: 43	srcs: [34]
# 無く		dst: 40	srcs: []
# （ブロードバンド接続普及後の		dst: 38	srcs: []
# 2010年に		dst: 40	srcs: [37]
# 初めて		dst: 40	srcs: []
# 提唱された）、		dst: 42	srcs: [36, 38, 39]
# データマイニングとしての		dst: 42	srcs: []
# 産業応用は		dst: 43	srcs: [40, 41]
# 行われなかった。		dst: 57	srcs: [28, 32, 33, 35, 42]
# しかし、		dst: 57	srcs: []
# ニューラルネットワークが		dst: 48	srcs: []
# 一般人も		dst: 47	srcs: []
# 巻き込んで		dst: 48	srcs: [46]
# 流行した		dst: 49	srcs: [45, 47]
# 事例としては		dst: 51	srcs: [48]
# 初めての		dst: 51	srcs: []
# 事例であり、		dst: 56	srcs: [49, 50]
# 2010年代の		dst: 53	srcs: []
# ディープラーニングブームの		dst: 54	srcs: [52]
# 前史とも		dst: 55	srcs: [53]
# 言える		dst: 56	srcs: [54]
# 社会現象と		dst: 57	srcs: [51, 55]
# 言える。		dst: -1	srcs: [43, 44, 56]
#
# 松下電器が		dst: 3	srcs: []
# 1985年頃から		dst: 3	srcs: []
# 人間が		dst: 3	srcs: []
# 持つような		dst: 4	srcs: [0, 1, 2]
# 曖昧さを		dst: 6	srcs: [3]
# 制御に		dst: 6	srcs: []
# 活かす		dst: 7	srcs: [4, 5]
# ファジィ制御についての		dst: 8	srcs: [6]
# 研究を		dst: 9	srcs: [7]
# 開始し、		dst: 15	srcs: [8]
# 1990年2月		dst: 11	srcs: []
# 1日に		dst: 15	srcs: [10]
# ファジィ洗濯機第1号である		dst: 13	srcs: []
# 「愛妻号Dayファジィ」の		dst: 14	srcs: [12]
# 発売に		dst: 15	srcs: [13]
# 漕ぎ着けた。		dst: 29	srcs: [9, 11, 14]
# 「愛妻号Dayファジィ」は		dst: 29	srcs: []
# 従来よりも		dst: 20	srcs: []
# 多数の		dst: 19	srcs: []
# センサーで		dst: 20	srcs: [18]
# 収集した		dst: 21	srcs: [17, 19]
# データに		dst: 22	srcs: [20]
# 基づいて、		dst: 25	srcs: [21]
# 柔軟に		dst: 25	srcs: []
# 運転を		dst: 25	srcs: []
# 最適化する		dst: 26	srcs: [22, 23, 24]
# 洗濯機で、		dst: 29	srcs: [25]
# 同種の		dst: 28	srcs: []
# 洗濯機としては		dst: 29	srcs: [27]
# 世界初であった。		dst: 46	srcs: [15, 16, 26, 28]
# ファジィ制御という		dst: 37	srcs: []
# 当時		dst: 37	srcs: []
# 最先端の		dst: 33	srcs: []
# 技術の		dst: 34	srcs: [32]
# 導入が		dst: 37	srcs: [33]
# バブル期の		dst: 36	srcs: []
# 高級路線にも		dst: 37	srcs: [35]
# マッチした		dst: 38	srcs: [30, 31, 34, 36]
# ことから、		dst: 46	srcs: [37]
# ファジィは		dst: 46	srcs: []
# 裏方の		dst: 41	srcs: []
# 制御技術であるにも		dst: 42	srcs: [40]
# 関わらず		dst: 46	srcs: [41]
# 世間の		dst: 45	srcs: []
# 大きな		dst: 45	srcs: []
# 注目を		dst: 46	srcs: [43, 44]
# 集めた。		dst: 56	srcs: [29, 38, 39, 42, 45]
# その		dst: 48	srcs: []
# 流行の		dst: 49	srcs: [47]
# 度合いは、		dst: 56	srcs: [48]
# 1990年の		dst: 51	srcs: []
# 新語・流行語大賞における		dst: 52	srcs: [50]
# 新語部門の		dst: 53	srcs: [51]
# 金賞で		dst: 55	srcs: [52]
# 「ファジィ」が		dst: 55	srcs: []
# 選ばれる		dst: 56	srcs: [53, 54]
# 程であった。		dst: 76	srcs: [46, 49, 55]
# その後に、		dst: 76	srcs: []
# 松下電器は		dst: 76	srcs: []
# ファジィルールの		dst: 61	srcs: []
# 煩雑な		dst: 61	srcs: []
# チューニングを		dst: 62	srcs: [59, 60]
# 自動化した		dst: 63	srcs: [61]
# ニューロファジィ制御を		dst: 64	srcs: [62]
# 開発し、		dst: 68	srcs: [63]
# 従来の		dst: 66	srcs: []
# ファジィ理論の		dst: 67	srcs: [65]
# 限界を		dst: 68	srcs: [66]
# 突破して		dst: 70	srcs: [64, 67]
# 学会で		dst: 70	srcs: []
# 評価されるだけでなく、		dst: 76	srcs: [68, 69]
# 白物家電への		dst: 72	srcs: []
# 応用にも		dst: 73	srcs: [71]
# 成功して		dst: 76	srcs: [72]
# 更なる		dst: 75	srcs: []
# ブームを		dst: 76	srcs: [74]
# 巻き起こした。		dst: 87	srcs: [56, 57, 58, 70, 73, 75]
# 松下電器の		dst: 78	srcs: []
# 試みの		dst: 79	srcs: [77]
# 成功を		dst: 80	srcs: [78]
# 受けて、		dst: 84	srcs: [79]
# 他社も		dst: 84	srcs: []
# 同様の		dst: 83	srcs: []
# 知的制御を		dst: 84	srcs: [82]
# 用いる		dst: 85	srcs: [80, 81, 83]
# 製品を		dst: 87	srcs: [84]
# 多数		dst: 87	srcs: []
# 発売した。		dst: 108	srcs: [76, 85, 86]
# 1990年代		dst: 89	srcs: []
# 中頃までは、		dst: 97	srcs: [88]
# メーカー各社による		dst: 91	srcs: []
# 一般向けの		dst: 92	srcs: [90]
# 白物家電の		dst: 93	srcs: [91]
# 売り文句として		dst: 97	srcs: [92]
# 知的制御技術の		dst: 95	srcs: []
# 名称が		dst: 97	srcs: [94]
# 大々的に		dst: 97	srcs: []
# 用いられており、		dst: 108	srcs: [89, 93, 95, 96]
# 洗濯機の		dst: 99	srcs: []
# 製品名では		dst: 108	srcs: [98]
# 「愛妻号DAYファジィ」，		dst: 101	srcs: []
# 掃除機の		dst: 102	srcs: [100]
# 分類としては		dst: 108	srcs: [101]
# 「ニューロ・ファジィ掃除機」，		dst: 104	srcs: []
# エアコンの		dst: 105	srcs: [103]
# 運転モードでは		dst: 108	srcs: [104]
# 「ニューロ自動」などの		dst: 107	srcs: []
# 名称が		dst: 108	srcs: [106]
# 付与されていた。		dst: -1	srcs: [87, 97, 99, 102, 105, 107]
#
# ニューロ，		dst: 1	srcs: []
# ファジィ，		dst: 2	srcs: [0]
# ニューロファジィという		dst: 3	srcs: [1]
# 手法は、		dst: 43	srcs: [2]
# 従来の		dst: 6	srcs: []
# 単純な		dst: 6	srcs: []
# オン・オフ制御や、		dst: 12	srcs: [4, 5]
# 対象を		dst: 10	srcs: []
# 数式で		dst: 10	srcs: []
# 客観的に		dst: 10	srcs: []
# モデル化する		dst: 12	srcs: [7, 8, 9]
# （この		dst: 12	srcs: []
# 作業は		dst: 19	srcs: [6, 10, 11]
# 対象が		dst: 16	srcs: []
# 複雑な		dst: 15	srcs: []
# 機構を		dst: 16	srcs: [14]
# 持つ		dst: 17	srcs: [13, 15]
# 場合は		dst: 19	srcs: [16]
# 極めて		dst: 19	srcs: []
# 難しくなる）		dst: 20	srcs: [12, 17, 18]
# 必要が		dst: 21	srcs: [19]
# ある		dst: 23	srcs: [20]
# PID制御や		dst: 23	srcs: []
# 現代制御等と		dst: 24	srcs: [21, 22]
# 比較して、		dst: 43	srcs: [23]
# 人間の		dst: 27	srcs: []
# 主観的な		dst: 27	srcs: []
# 経験則や		dst: 30	srcs: [25, 26]
# 計測した		dst: 29	srcs: []
# データの		dst: 30	srcs: [28]
# 特徴が		dst: 32	srcs: [27, 29]
# 利用可能と		dst: 32	srcs: []
# なる		dst: 33	srcs: [30, 31]
# ファジィ、		dst: 34	srcs: [32]
# ニューロ、		dst: 35	srcs: [33]
# ニューロファジィは		dst: 43	srcs: [34]
# 開発工数を		dst: 37	srcs: []
# 抑えながら、		dst: 41	srcs: [36]
# 環境適応時の		dst: 39	srcs: []
# 柔軟性を		dst: 41	srcs: [38]
# 高く		dst: 41	srcs: []
# できるという		dst: 42	srcs: [37, 39, 40]
# 利点が		dst: 43	srcs: [41]
# あった。		dst: 60	srcs: [3, 24, 35, 42]
# しかし、		dst: 60	srcs: []
# 開発者らの		dst: 46	srcs: []
# 努力にも		dst: 47	srcs: [45]
# 関わらず、		dst: 60	srcs: [46]
# 計算能力や		dst: 50	srcs: []
# 収集可能な		dst: 50	srcs: []
# データ量の		dst: 51	srcs: [48, 49]
# 少なさから、		dst: 57	srcs: [50]
# 既存の		dst: 53	srcs: []
# 工作機械や		dst: 55	srcs: [52]
# 家電製品の		dst: 55	srcs: []
# 制御を		dst: 57	srcs: [53, 54]
# 多少		dst: 57	srcs: []
# 改善する		dst: 58	srcs: [51, 55, 56]
# 程度で		dst: 60	srcs: [57]
# 限界を		dst: 60	srcs: []
# 迎えた。		dst: 74	srcs: [43, 44, 47, 58, 59]
# 理論的にも		dst: 66	srcs: []
# ファジィ集合と		dst: 63	srcs: []
# 深層学習が		dst: 66	srcs: [62]
# 不可能な		dst: 65	srcs: []
# ニューラルネットワークの		dst: 66	srcs: [64]
# 組み合わせであり、		dst: 74	srcs: [61, 63, 65]
# 計算リソースや		dst: 68	srcs: []
# データが		dst: 70	srcs: [67]
# 潤沢に		dst: 70	srcs: []
# 与えられたとしても、		dst: 74	srcs: [68, 69]
# 認識精度の		dst: 72	srcs: []
# 向上には		dst: 74	srcs: [71]
# 限界が		dst: 74	srcs: []
# あった。		dst: -1	srcs: [60, 66, 70, 72, 73]
#
# 以降、		dst: 16	srcs: []
# 計算機の		dst: 2	srcs: []
# 能力限界から		dst: 6	srcs: [1]
# 理論の		dst: 4	srcs: []
# 改善は		dst: 6	srcs: [3]
# 遅々として		dst: 6	srcs: []
# 進まず、		dst: 9	srcs: [2, 4, 5]
# 目立った		dst: 8	srcs: []
# 進展は		dst: 9	srcs: [7]
# 無くなり、		dst: 16	srcs: [6, 8]
# 1990年代		dst: 11	srcs: []
# 末には		dst: 16	srcs: [10]
# 知的制御を		dst: 13	srcs: []
# 搭載する		dst: 14	srcs: [12]
# 白物家電が		dst: 16	srcs: [13]
# 大多数に		dst: 16	srcs: []
# なった		dst: 17	srcs: [0, 9, 11, 14, 15]
# ことで、		dst: 21	srcs: [16]
# 売り		dst: 21	srcs: []
# 文句としての		dst: 20	srcs: []
# ブームは		dst: 21	srcs: [19]
# 去った。		dst: 39	srcs: [17, 18, 20]
# ブーム後は		dst: 24	srcs: []
# 一般には		dst: 24	srcs: []
# 意識されなくなったが、		dst: 39	srcs: [22, 23]
# 現在では		dst: 39	srcs: []
# 裏方の		dst: 27	srcs: []
# 技術として、		dst: 39	srcs: [26]
# 家電製品のみならず、		dst: 35	srcs: []
# 雨水の		dst: 30	srcs: []
# 排水，		dst: 33	srcs: [29]
# 駐車場，		dst: 33	srcs: []
# ビルの		dst: 33	srcs: []
# 管理システムなどの		dst: 34	srcs: [30, 31, 32]
# 社会インフラにも		dst: 35	srcs: [33]
# 使われ、		dst: 39	srcs: [28, 34]
# 十分に		dst: 39	srcs: []
# 性能と		dst: 38	srcs: []
# 安定性が		dst: 39	srcs: [37]
# 実証されている。		dst: 49	srcs: [21, 24, 25, 27, 35, 36, 38]
# 2003年頃には、		dst: 49	srcs: []
# 人間が		dst: 42	srcs: []
# 設計した		dst: 43	srcs: [41]
# オントロジー		dst: 45	srcs: [42]
# （ファジィルールとして		dst: 45	srcs: []
# 表現する）を		dst: 46	srcs: [43, 44]
# 利活用する		dst: 47	srcs: [45]
# ネットワーク・インテリジェンスという		dst: 48	srcs: [46]
# 分野に		dst: 49	srcs: [47]
# 発展した。		dst: -1	srcs: [39, 40, 48]
#
# 2005年、		dst: 20	srcs: []
# レイ・カーツワイルは		dst: 20	srcs: []
# 著作で、		dst: 20	srcs: []
# 「圧倒的な		dst: 4	srcs: []
# 人工知能が		dst: 8	srcs: [3]
# 知識・知能の		dst: 6	srcs: []
# 点で		dst: 8	srcs: [5]
# 人間を		dst: 8	srcs: []
# 超越し、		dst: 13	srcs: [4, 6, 7]
# 科学技術の		dst: 10	srcs: []
# 進歩を		dst: 11	srcs: [9]
# 担い		dst: 13	srcs: [10]
# 世界を		dst: 13	srcs: []
# 変革する		dst: 14	srcs: [8, 11, 12]
# 技術的特異点		dst: 15	srcs: [13]
# （シンギュラリティ）が		dst: 17	srcs: [14]
# 2045年にも		dst: 17	srcs: []
# 訪れる」と		dst: 18	srcs: [15, 16]
# する		dst: 19	srcs: [17]
# 説を		dst: 20	srcs: [18]
# 発表した。		dst: -1	srcs: [0, 1, 2, 19]
#
# 2006年に、		dst: 6	srcs: []
# ジェフリー・ヒントンらの		dst: 2	srcs: []
# 研究チームにより		dst: 6	srcs: [1]
# オートエンコーダによる		dst: 4	srcs: []
# ニューラルネットワークの		dst: 5	srcs: [3]
# 深層化手法が		dst: 6	srcs: [4]
# 提案された		dst: 10	srcs: [0, 2, 5]
# （現在の		dst: 8	srcs: []
# ディープラーニングの		dst: 10	srcs: [7]
# 直接的な		dst: 10	srcs: []
# 起源）。		dst: -1	srcs: [6, 8, 9]
#
# 2010年代に		dst: 1	srcs: []
# 入り、		dst: 8	srcs: [0]
# 膨大な		dst: 3	srcs: []
# データを		dst: 4	srcs: [2]
# 扱う		dst: 5	srcs: [3]
# 研究開発の		dst: 6	srcs: [4]
# ための		dst: 7	srcs: [5]
# 環境が		dst: 8	srcs: [6]
# 整備された		dst: 9	srcs: [1, 7]
# ことで、		dst: 14	srcs: [8]
# AI関連の		dst: 11	srcs: []
# 研究が		dst: 14	srcs: [10]
# 再び		dst: 14	srcs: []
# 大きく		dst: 14	srcs: []
# 前進し始めた。		dst: -1	srcs: [9, 11, 12, 13]
#
# 2010年に		dst: 4	srcs: []
# 英国エコノミスト誌で		dst: 4	srcs: []
# 「ビッグデータ」という		dst: 3	srcs: []
# 用語が		dst: 4	srcs: [2]
# 提唱された。		dst: 28	srcs: [0, 1, 3]
# 同年に		dst: 28	srcs: []
# 質問応答システムの		dst: 7	srcs: []
# ワトソンが、		dst: 28	srcs: [6]
# クイズ番組		dst: 15	srcs: []
# 「ジェパディ!」の		dst: 10	srcs: []
# 練習戦で		dst: 12	srcs: [9]
# 人間に		dst: 12	srcs: []
# 勝利し、		dst: 15	srcs: [10, 11]
# 大きな		dst: 14	srcs: []
# ニュースと		dst: 15	srcs: [13]
# なった。		dst: 28	srcs: [8, 12, 14]
# 2012年に		dst: 23	srcs: []
# 画像処理コンテストで		dst: 23	srcs: []
# ジェフリー・ヒントン氏の		dst: 19	srcs: []
# チームが		dst: 23	srcs: [18]
# 従来手法からの		dst: 22	srcs: []
# 大幅な		dst: 22	srcs: []
# 精度改善を		dst: 23	srcs: [20, 21]
# 果たした		dst: 24	srcs: [16, 17, 19, 22]
# 上で		dst: 25	srcs: [23]
# 優勝した		dst: 26	srcs: [24]
# ことで、		dst: 28	srcs: [25]
# 第三次AIブームが		dst: 28	srcs: []
# 始まった。		dst: -1	srcs: [4, 5, 7, 15, 26, 27]
#
# 2013年には		dst: 9	srcs: []
# 国立情報学研究所や		dst: 2	srcs: []
# 富士通研究所の		dst: 3	srcs: [1]
# 研究チームが		dst: 4	srcs: [2]
# 開発した		dst: 5	srcs: [3]
# 「東ロボくん」で		dst: 8	srcs: [4]
# 東京大学入試の		dst: 7	srcs: []
# 模擬試験に		dst: 8	srcs: [6]
# 挑んだと		dst: 9	srcs: [5, 7]
# 発表した。		dst: 23	srcs: [0, 8]
# 数式の		dst: 11	srcs: []
# 計算や		dst: 13	srcs: [10]
# 単語の		dst: 13	srcs: []
# 解析にあたる		dst: 14	srcs: [11, 12]
# 専用プログラムを		dst: 15	srcs: [13]
# 使い、		dst: 23	srcs: [14]
# 実際に		dst: 18	srcs: []
# 受験生が		dst: 18	srcs: []
# 臨んだ		dst: 19	srcs: [16, 17]
# 大学入試センター試験と		dst: 22	srcs: [18]
# 東大の		dst: 21	srcs: []
# 2次試験の		dst: 22	srcs: [20]
# 問題を		dst: 23	srcs: [19, 21]
# 解読した。		dst: 31	srcs: [9, 15, 22]
# 代々木ゼミナールの		dst: 25	srcs: []
# 判定では		dst: 31	srcs: [24]
# 「東大の		dst: 27	srcs: []
# 合格は		dst: 28	srcs: [26]
# 難しいが、		dst: 31	srcs: [27]
# 私立大学には		dst: 31	srcs: []
# 合格できる		dst: 31	srcs: []
# 水準」だった。		dst: -1	srcs: [23, 25, 28, 29, 30]
#
# 2014年には、		dst: 16	srcs: []
# 日本の		dst: 2	srcs: []
# 人工知能学者である		dst: 3	srcs: [1]
# 齊藤元章により、		dst: 5	srcs: [2]
# 特異点に		dst: 5	srcs: []
# 先立ち、		dst: 13	srcs: [3, 4]
# オートメーション化と		dst: 8	srcs: []
# コンピューター技術の		dst: 8	srcs: []
# 進歩により		dst: 13	srcs: [6, 7]
# 衣食住の		dst: 10	srcs: []
# 生産コストが		dst: 13	srcs: [9]
# ゼロに		dst: 12	srcs: []
# 限りなく		dst: 13	srcs: [11]
# 近づくという		dst: 14	srcs: [5, 8, 10, 12]
# プレ・シンギュラリティという		dst: 15	srcs: [13]
# 概念も		dst: 16	srcs: [14]
# 提唱された。		dst: -1	srcs: [0, 15]
#
# ジェフ・ホーキンスが、		dst: 4	srcs: []
# 実現に		dst: 2	srcs: []
# 向けて		dst: 4	srcs: [1]
# 研究を		dst: 4	srcs: []
# 続けているが、		dst: 13	srcs: [0, 2, 3]
# 著書		dst: 6	srcs: []
# 『考える		dst: 8	srcs: [5]
# 脳考える		dst: 8	srcs: []
# コンピューター』の		dst: 9	srcs: [6, 7]
# 中で		dst: 13	srcs: [8]
# 自己連想記憶理論という		dst: 11	srcs: []
# 独自の		dst: 12	srcs: [10]
# 理論を		dst: 13	srcs: [11]
# 展開している。		dst: -1	srcs: [4, 9, 12]
#
# 世界各国において、		dst: 5	srcs: []
# 軍事・民間共に		dst: 5	srcs: []
# 実用化に		dst: 3	srcs: []
# 向け		dst: 5	srcs: [2]
# 研究開発が		dst: 5	srcs: []
# 進んでいるが、		dst: 10	srcs: [0, 1, 3, 4]
# とくに		dst: 10	srcs: []
# 無人戦闘機や		dst: 8	srcs: []
# 無人自動車ロボットカーの		dst: 9	srcs: [7]
# 開発が		dst: 10	srcs: [8]
# 進行している		dst: 11	srcs: [5, 6, 9]
# ものの、		dst: 25	srcs: [10]
# 2010年代には		dst: 20	srcs: []
# まだ		dst: 14	srcs: []
# 完全な		dst: 15	srcs: [13]
# 自動化は		dst: 20	srcs: [14]
# 試験的な		dst: 17	srcs: []
# ものに		dst: 18	srcs: [16]
# 留まった		dst: 19	srcs: [17]
# （UCAVは		dst: 20	srcs: [18]
# 利用されているが、		dst: 25	srcs: [12, 15, 19]
# 一部操作は		dst: 25	srcs: []
# 地上から		dst: 23	srcs: []
# 行っている		dst: 24	srcs: [22]
# ものが		dst: 25	srcs: [23]
# 多い）。		dst: -1	srcs: [11, 20, 21, 24]
#
# ロボット向けとしては、		dst: 6	srcs: []
# CSAILの		dst: 2	srcs: []
# ロドニー・ブルックスが		dst: 3	srcs: [1]
# 提唱した		dst: 4	srcs: [2]
# 包摂アーキテクチャという		dst: 5	srcs: [3]
# 理論が		dst: 6	srcs: [4]
# 登場している。		dst: 22	srcs: [0, 5]
# これは		dst: 22	srcs: []
# 従来型の		dst: 13	srcs: []
# 「我思う、		dst: 10	srcs: []
# 故に		dst: 12	srcs: [9]
# 我		dst: 12	srcs: []
# あり」の		dst: 13	srcs: [10, 11]
# 知が		dst: 14	srcs: [8, 12]
# 先行する		dst: 15	srcs: [13]
# ものではなく、		dst: 22	srcs: [14]
# 体の		dst: 17	srcs: []
# 神経ネットワークのみを		dst: 18	srcs: [16]
# 用いて		dst: 20	srcs: [17]
# 環境から		dst: 20	srcs: []
# 学習する		dst: 21	srcs: [18, 19]
# 行動型システムを		dst: 22	srcs: [20]
# 用いている。		dst: 36	srcs: [6, 7, 15, 21]
# これに		dst: 24	srcs: []
# 基づいた		dst: 25	srcs: [23]
# ゲンギスと		dst: 26	srcs: [24]
# 呼ばれる		dst: 27	srcs: [25]
# 六本足の		dst: 28	srcs: [26]
# ロボットは、		dst: 36	srcs: [27]
# いわゆる		dst: 30	srcs: []
# 「脳」を		dst: 31	srcs: [29]
# 持たないにも		dst: 32	srcs: [30]
# 関わらず、		dst: 36	srcs: [31]
# まるで		dst: 34	srcs: []
# 生きているかの		dst: 35	srcs: [33]
# ように		dst: 36	srcs: [34]
# 行動する。		dst: -1	srcs: [22, 28, 32, 35]
#
# 2015年		dst: 1	srcs: []
# 10月に		dst: 3	srcs: [0]
# 米DeepMind社が		dst: 3	srcs: []
# 作成した		dst: 4	srcs: [1, 2]
# 「AlphaGo」が		dst: 11	srcs: [3]
# 人間の		dst: 6	srcs: []
# プロ囲碁棋士に		dst: 7	srcs: [5]
# 勝利して以降は		dst: 11	srcs: [6]
# ディープラーニングと		dst: 9	srcs: []
# 呼ばれる		dst: 10	srcs: [8]
# 手法が		dst: 11	srcs: [9]
# 注目され、		dst: 20	srcs: [4, 7, 10]
# 人工知能自体の		dst: 13	srcs: []
# 研究の		dst: 14	srcs: [12]
# 他にも、		dst: 18	srcs: [13]
# 人工知能が		dst: 17	srcs: []
# 雇用などに		dst: 17	srcs: []
# 与える		dst: 18	srcs: [15, 16]
# 影響についても		dst: 20	srcs: [14, 17]
# 研究が		dst: 20	srcs: []
# 進められている。		dst: -1	srcs: [11, 18, 19]
#
# 2016年		dst: 1	srcs: []
# 10月、		dst: 29	srcs: [0]
# DeepMindが、		dst: 13	srcs: []
# 入力された		dst: 4	srcs: []
# 情報の		dst: 5	srcs: [3]
# 関連性を		dst: 6	srcs: [4]
# 導き出し		dst: 10	srcs: [5]
# 仮説に		dst: 8	srcs: []
# 近い		dst: 9	srcs: [7]
# ものを		dst: 10	srcs: [8]
# 導き出す		dst: 11	srcs: [6, 9]
# 人工知能技術		dst: 12	srcs: [10]
# 「ディファレンシャブル・ニューラル・コンピューター」を		dst: 13	srcs: [11]
# 発表し、		dst: 29	srcs: [2, 12]
# 同年		dst: 15	srcs: []
# 11月、		dst: 29	srcs: [14]
# 大量の		dst: 17	srcs: []
# データが		dst: 20	srcs: [16]
# 不要の		dst: 19	srcs: []
# 「ワンショット学習」を		dst: 20	srcs: [18]
# 可能にする		dst: 21	srcs: [17, 19]
# 深層学習システムを、		dst: 29	srcs: [20]
# 翌2017年		dst: 23	srcs: []
# 6月、		dst: 29	srcs: [22]
# 関係推論のような		dst: 25	srcs: []
# 人間並みの		dst: 26	srcs: [24]
# 認識能力を		dst: 27	srcs: [25]
# 持つ		dst: 28	srcs: [26]
# システムを		dst: 29	srcs: [27]
# 開発。		dst: 33	srcs: [1, 13, 15, 21, 23, 28]
# 2017年		dst: 31	srcs: []
# 8月には、		dst: 33	srcs: [30]
# 記号接地問題(シンボルグラウンディング問題)を		dst: 33	srcs: []
# 解決した。		dst: -1	srcs: [29, 31, 32]
#
# 2006年の		dst: 1	srcs: []
# ディープラーニングの		dst: 2	srcs: [0]
# 発明と、		dst: 5	srcs: [1]
# 2010年以降の		dst: 4	srcs: []
# ビッグデータ収集環境の		dst: 5	srcs: [3]
# 整備、		dst: 9	srcs: [2, 4]
# 計算資源と		dst: 7	srcs: []
# なる		dst: 8	srcs: [6]
# GPUの		dst: 9	srcs: [7]
# 高性能化により、		dst: 17	srcs: [5, 8]
# 2012年に		dst: 17	srcs: []
# ディープラーニングが		dst: 17	srcs: []
# 画像処理コンテストで		dst: 16	srcs: []
# 他の		dst: 14	srcs: []
# 手法に		dst: 16	srcs: [13]
# 圧倒的大差を		dst: 16	srcs: []
# 付けて		dst: 17	srcs: [12, 14, 15]
# 優勝した		dst: 18	srcs: [9, 10, 11, 16]
# ことで、		dst: 28	srcs: [17]
# 技術的特異点という		dst: 20	srcs: []
# 概念は		dst: 28	srcs: [19]
# 急速に		dst: 25	srcs: []
# 世界中の		dst: 23	srcs: []
# 識者の		dst: 24	srcs: [22]
# 注目を		dst: 25	srcs: [23]
# 集め、		dst: 28	srcs: [21, 24]
# 現実味を		dst: 27	srcs: []
# 持って		dst: 28	srcs: [26]
# 受け止められるようになった。		dst: 53	srcs: [18, 20, 25, 27]
# ディープラーニングの		dst: 30	srcs: []
# 発明と		dst: 32	srcs: [29]
# 急速な		dst: 32	srcs: []
# 普及を		dst: 33	srcs: [30, 31]
# 受けて、		dst: 53	srcs: [32]
# 研究開発の		dst: 35	srcs: []
# 現場においては、		dst: 53	srcs: [34]
# デミス・ハサビス		dst: 37	srcs: []
# 率いる		dst: 38	srcs: [36]
# DeepMindを		dst: 39	srcs: [37]
# 筆頭に、		dst: 53	srcs: [38]
# Vicarious、		dst: 41	srcs: []
# IBMCorticalLearningCenter、		dst: 42	srcs: [40]
# 全脳アーキテクチャ、		dst: 43	srcs: [41]
# PEZYComputing、		dst: 44	srcs: [42]
# OpenCog、		dst: 45	srcs: [43]
# GoodAI、		dst: 46	srcs: [44]
# nnaisense、		dst: 47	srcs: [45]
# IBMSyNAPSE等、		dst: 48	srcs: [46]
# 汎用人工知能		dst: 49	srcs: [47]
# （AGI）を		dst: 50	srcs: [48]
# 開発する		dst: 51	srcs: [49]
# プロジェクトが		dst: 53	srcs: [50]
# 数多く		dst: 53	srcs: []
# 立ち上げられている。		dst: 65	srcs: [28, 33, 35, 39, 51, 52]
# これらの		dst: 55	srcs: []
# 研究開発の		dst: 56	srcs: [54]
# 現場では、		dst: 65	srcs: [55]
# 脳を		dst: 58	srcs: []
# リバースエンジニアリングして		dst: 59	srcs: [57]
# 構築された		dst: 61	srcs: [58]
# 神経科学と		dst: 61	srcs: []
# 機械学習を		dst: 62	srcs: [59, 60]
# 組み合わせる		dst: 63	srcs: [61]
# アプローチが		dst: 64	srcs: [62]
# 有望と		dst: 65	srcs: [63]
# されている。		dst: 82	srcs: [53, 56, 64]
# 結果として、		dst: 82	srcs: []
# HierarchicalTemporalMemory(HTM)理論、		dst: 68	srcs: []
# ComplementaryLearningSystems(CLS)理論の		dst: 69	srcs: [67]
# 更新版等、		dst: 71	srcs: [68]
# 単一の		dst: 71	srcs: []
# タスクのみを		dst: 72	srcs: [69, 70]
# 扱う		dst: 73	srcs: [71]
# ディープラーニングから		dst: 76	srcs: [72]
# 更に		dst: 76	srcs: []
# 一歩		dst: 76	srcs: []
# 進んだ、		dst: 78	srcs: [73, 74, 75]
# 複数の		dst: 78	srcs: []
# タスクを		dst: 80	srcs: [76, 77]
# 同時に		dst: 80	srcs: []
# 扱う		dst: 81	srcs: [78, 79]
# 理論が		dst: 82	srcs: [80]
# 提唱され始めている。		dst: -1	srcs: [65, 66, 81]
#
# 3Dゲームのような		dst: 1	srcs: []
# 仮想空間で		dst: 3	srcs: [0]
# モデルを		dst: 3	srcs: []
# 動かし		dst: 7	srcs: [1, 2]
# 現実世界の		dst: 5	srcs: []
# ことを		dst: 7	srcs: [4]
# 高速に		dst: 7	srcs: []
# 学ばせるといった		dst: 8	srcs: [3, 5, 6]
# ことも		dst: 11	srcs: [7]
# 大きな		dst: 10	srcs: []
# 成果を		dst: 11	srcs: [9]
# 上げている		dst: 13	srcs: [8, 10]
# （シミュレーションによる		dst: 13	srcs: []
# 学習）。		dst: -1	srcs: [11, 12]
#
# また、		dst: 34	srcs: []
# 数は		dst: 2	srcs: []
# 少ないが		dst: 6	srcs: [1]
# AGIだけでは		dst: 6	srcs: []
# 知能の		dst: 5	srcs: []
# 再現は		dst: 6	srcs: [4]
# 不可能と		dst: 7	srcs: [2, 3, 5]
# 考えて、		dst: 27	srcs: [6]
# 身体知を		dst: 9	srcs: []
# 再現する		dst: 10	srcs: [8]
# ために、		dst: 12	srcs: [9]
# 全人体シミュレーションが		dst: 12	srcs: []
# 必要だと		dst: 13	srcs: [10, 11]
# する		dst: 14	srcs: [12]
# 研究者やより		dst: 16	srcs: [13]
# 生物に		dst: 16	srcs: []
# 近い		dst: 17	srcs: [14, 15]
# 振る舞いを		dst: 18	srcs: [16]
# 見せる		dst: 19	srcs: [17]
# AL		dst: 24	srcs: [18]
# （人工生命）の		dst: 21	srcs: []
# 作成に		dst: 22	srcs: [20]
# 挑む		dst: 23	srcs: [21]
# 研究者、		dst: 24	srcs: [22]
# 知能と		dst: 26	srcs: [19, 23]
# 密接な		dst: 26	srcs: []
# 関係に		dst: 27	srcs: [24, 25]
# あると		dst: 28	srcs: [7, 26]
# 思われる		dst: 29	srcs: [27]
# 意識の		dst: 30	srcs: [28]
# デジタル的再現		dst: 31	srcs: [29]
# （人工意識）に		dst: 32	srcs: [30]
# 挑戦する		dst: 33	srcs: [31]
# 研究者も		dst: 34	srcs: [32]
# いる。		dst: -1	srcs: [0, 33]
#
# リーズナブルな		dst: 1	srcs: []
# コストで		dst: 5	srcs: [0]
# 大量の		dst: 3	srcs: []
# 計算リソースが		dst: 5	srcs: [2]
# 手に		dst: 5	srcs: []
# 入るようになった		dst: 6	srcs: [1, 3, 4]
# ことで、		dst: 16	srcs: [5]
# ビッグデータが		dst: 8	srcs: []
# 出現し、		dst: 16	srcs: [7]
# 企業が		dst: 16	srcs: []
# 膨大な		dst: 11	srcs: []
# データの		dst: 12	srcs: [10]
# 活用に		dst: 16	srcs: [11]
# 極めて		dst: 14	srcs: []
# 強い		dst: 15	srcs: [13]
# 関心を		dst: 16	srcs: [14]
# 寄せており、		dst: 24	srcs: [6, 8, 9, 12, 15]
# 全世界的に		dst: 21	srcs: []
# 民間企業主導で		dst: 21	srcs: []
# 莫大な		dst: 20	srcs: []
# 投資を		dst: 21	srcs: [19]
# 行って		dst: 24	srcs: [17, 18, 20]
# 人工知能に関する		dst: 23	srcs: []
# 研究開発競争が		dst: 24	srcs: [22]
# 展開されている。		dst: 47	srcs: [16, 21, 23]
# また、		dst: 47	srcs: []
# 2011年の		dst: 27	srcs: []
# D-WaveSystemsによる		dst: 28	srcs: [26]
# 量子アニーリング方式の		dst: 29	srcs: [27]
# 製品化を		dst: 30	srcs: [28]
# 嚆矢として、		dst: 37	srcs: [29]
# 量子コンピュータという		dst: 32	srcs: []
# 超々並列処理が		dst: 33	srcs: [31]
# 可能な		dst: 34	srcs: [32]
# 次世代の		dst: 35	srcs: [33]
# ITインフラが		dst: 37	srcs: [34]
# 急速に		dst: 37	srcs: []
# 実用化され始めた		dst: 38	srcs: [30, 35, 36]
# 事で、		dst: 47	srcs: [37]
# 人工知能の		dst: 40	srcs: []
# 高速化にも		dst: 42	srcs: [39]
# 深く		dst: 42	srcs: []
# 関わる		dst: 43	srcs: [40, 41]
# 組み合わせ最適化問題を		dst: 45	srcs: [42]
# リアルタイムに		dst: 45	srcs: []
# 解決できる		dst: 46	srcs: [43, 44]
# 環境が		dst: 47	srcs: [45]
# 整備され始めている。		dst: 61	srcs: [24, 25, 38, 46]
# この		dst: 49	srcs: []
# 動向を		dst: 50	srcs: [48]
# 受ける		dst: 51	srcs: [49]
# 形で、		dst: 61	srcs: [50]
# 2016年頃から、		dst: 61	srcs: []
# 一般向けの		dst: 54	srcs: []
# ニュース番組でも		dst: 61	srcs: [53]
# 人工知能の		dst: 59	srcs: []
# 研究開発や		dst: 59	srcs: []
# 新しい		dst: 59	srcs: []
# サービス展開や		dst: 59	srcs: []
# 量子コンピュータに関する		dst: 60	srcs: [55, 56, 57, 58]
# 報道が		dst: 61	srcs: [59]
# 目立つようになった。		dst: -1	srcs: [47, 51, 52, 54, 60]
#
# 2017年には		dst: 21	srcs: []
# イーロン・マスクが、		dst: 7	srcs: []
# 急速に		dst: 3	srcs: []
# 進化し続ける		dst: 4	srcs: [2]
# 人工知能に対して		dst: 7	srcs: [3]
# 人間が		dst: 7	srcs: []
# 遅れを		dst: 7	srcs: []
# 取らないようにする		dst: 8	srcs: [1, 4, 5, 6]
# ために、		dst: 16	srcs: [7]
# 人間の		dst: 10	srcs: []
# 脳を		dst: 12	srcs: [9]
# 機械に		dst: 12	srcs: []
# 接続する		dst: 13	srcs: [10, 11]
# ブレイン・マシン・インターフェースを		dst: 14	srcs: [12]
# 研究開発する		dst: 15	srcs: [13]
# ニューラ・リンク社を		dst: 16	srcs: [14]
# 立ち上げていた		dst: 17	srcs: [8, 15]
# ことを		dst: 18	srcs: [16]
# 公表し、		dst: 21	srcs: [17]
# 世界中で		dst: 21	srcs: []
# 話題に		dst: 21	srcs: []
# なった。		dst: 27	srcs: [0, 18, 19, 20]
# ブレイン・マシン・インターフェースにより、		dst: 27	srcs: []
# 人の		dst: 24	srcs: []
# インターネットが		dst: 25	srcs: [23]
# 出現する		dst: 26	srcs: [24]
# 事が		dst: 27	srcs: [25]
# 予測されている。		dst: -1	srcs: [21, 22, 26]
#
# 2017年		dst: 1	srcs: []
# 10月には		dst: 7	srcs: [0]
# ジェフリー・ヒントンにより		dst: 7	srcs: []
# 要素間の		dst: 5	srcs: []
# 相対的な		dst: 5	srcs: []
# 位置関係まで		dst: 6	srcs: [3, 4]
# 含めて		dst: 7	srcs: [5]
# 学習できる		dst: 8	srcs: [1, 2, 6]
# カプセルネットワークが		dst: 9	srcs: [7]
# 提唱された。		dst: -1	srcs: [8]
#
# 2018年		dst: 1	srcs: []
# 3月		dst: 2	srcs: [0]
# 16日の		dst: 3	srcs: [1]
# 国際大学GLOCOMの		dst: 4	srcs: [2]
# 提言に		dst: 5	srcs: [3]
# よると、		dst: 12	srcs: [4]
# 課題解決型の		dst: 7	srcs: []
# AIを		dst: 8	srcs: [6]
# 活用する		dst: 9	srcs: [7]
# 事で		dst: 11	srcs: [8]
# 社会変革に		dst: 11	srcs: []
# 寄与できると		dst: 12	srcs: [9, 10]
# 分析されている。		dst: -1	srcs: [5, 11]
#
# 2018年		dst: 1	srcs: []
# 8月、		dst: 13	srcs: [0]
# OpenAIが		dst: 4	srcs: []
# 好奇心を		dst: 4	srcs: []
# 実装し		dst: 11	srcs: [2, 3]
# ノーゲームスコア、		dst: 6	srcs: []
# ノーゴール、		dst: 7	srcs: [5]
# 無報酬で		dst: 11	srcs: [6]
# 目的		dst: 9	srcs: []
# なき		dst: 10	srcs: [8]
# 探索を		dst: 11	srcs: [9]
# 行う		dst: 12	srcs: [4, 7, 10]
# AIを		dst: 13	srcs: [11]
# 公表。		dst: 18	srcs: [1, 12]
# これまでの		dst: 15	srcs: []
# AIで		dst: 17	srcs: [14]
# 最も		dst: 17	srcs: []
# 人間らしいと		dst: 18	srcs: [15, 16]
# いう。		dst: -1	srcs: [13, 17]
#
# 2018年		dst: 1	srcs: []
# 9月、		dst: 13	srcs: [0]
# MITリンカーン研究所は		dst: 13	srcs: []
# 従来ブラックボックスであった		dst: 4	srcs: []
# ニューラルネットワークの		dst: 5	srcs: [3]
# 推論を		dst: 9	srcs: [4]
# どのような		dst: 7	srcs: []
# 段階を		dst: 8	srcs: [6]
# 経て		dst: 9	srcs: [7]
# 識別したのかが		dst: 11	srcs: [5, 8]
# 明確に		dst: 11	srcs: []
# 分かる		dst: 12	srcs: [9, 10]
# アーキテクチャを		dst: 13	srcs: [11]
# 開発した。		dst: -1	srcs: [1, 2, 12]
#
# 2019年に		dst: 1	srcs: []
# 入ると		dst: 5	srcs: [0]
# これまで		dst: 5	srcs: []
# 深層学習では		dst: 4	srcs: []
# 困難と		dst: 5	srcs: [3]
# されてきた		dst: 6	srcs: [1, 2, 4]
# 言語処理において		dst: 9	srcs: [5]
# 大きな		dst: 8	srcs: []
# 進展が		dst: 9	srcs: [7]
# あり、		dst: 15	srcs: [6, 8]
# Wikipediaなどを		dst: 11	srcs: []
# 使用した		dst: 12	srcs: [10]
# 読解テストで		dst: 14	srcs: [11]
# 人間を		dst: 14	srcs: []
# 上回るに		dst: 15	srcs: [12, 13]
# 至った。		dst: 18	srcs: [9, 14]
# (BERT、		dst: 17	srcs: []
# ROBERT。		dst: 18	srcs: [16]
# )		dst: -1	srcs: [15, 17]
#
# アメリカでは		dst: 6	srcs: []
# 2013年に		dst: 6	srcs: []
# 時の		dst: 3	srcs: []
# 大統領バラク・オバマが		dst: 6	srcs: [2]
# 脳研究プロジェクト		dst: 5	srcs: []
# 「」を		dst: 6	srcs: [4]
# 発表。		dst: -1	srcs: [0, 1, 3, 5]
#
# Googleは		dst: 10	srcs: []
# アレン脳科学研究所と		dst: 2	srcs: []
# 連携し		dst: 4	srcs: [1]
# 脳スキャンによって		dst: 4	srcs: []
# 生まれた		dst: 6	srcs: [2, 3]
# 大量の		dst: 6	srcs: []
# データを		dst: 7	srcs: [4, 5]
# 処理する		dst: 8	srcs: [6]
# ための		dst: 9	srcs: [7]
# ソフトウェアを		dst: 10	srcs: [8]
# 開発している。		dst: 19	srcs: [0, 9]
# 2016年の		dst: 12	srcs: []
# 時点で、		dst: 19	srcs: [11]
# Googleが		dst: 14	srcs: []
# 管理している		dst: 15	srcs: [13]
# Brainmapの		dst: 16	srcs: [14]
# データ量は		dst: 19	srcs: [15]
# すでに		dst: 19	srcs: []
# 1Zettaバイトに		dst: 19	srcs: []
# 達していると		dst: 20	srcs: [10, 12, 16, 17, 18]
# いう。		dst: 31	srcs: [19]
# Googleは、		dst: 25	srcs: []
# ドイツの		dst: 23	srcs: []
# マックスプランク研究所とも		dst: 25	srcs: [22]
# 共同研究を		dst: 25	srcs: []
# 始めており、		dst: 31	srcs: [21, 23, 24]
# 脳の		dst: 27	srcs: []
# 電子顕微鏡写真から		dst: 29	srcs: [26]
# 神経回路を		dst: 29	srcs: []
# 再構成するという		dst: 30	srcs: [27, 28]
# 研究を		dst: 31	srcs: [29]
# 行っている。		dst: -1	srcs: [20, 25, 30]
#
# 中国では		dst: 11	srcs: []
# 2016年の		dst: 2	srcs: []
# 第13次5カ年計画から		dst: 5	srcs: [1]
# AIを		dst: 5	srcs: []
# 国家プロジェクトに		dst: 5	srcs: []
# 位置づけ、		dst: 7	srcs: [2, 3, 4]
# 脳研究プロジェクトとしても		dst: 7	srcs: []
# 立ち上げ、		dst: 11	srcs: [5, 6]
# 官民一体で		dst: 11	srcs: []
# AIの		dst: 10	srcs: []
# 研究開発を		dst: 11	srcs: [9]
# 推進してる。		dst: 20	srcs: [0, 7, 8, 10]
# 中国の		dst: 13	srcs: []
# 教育機関では		dst: 20	srcs: [12]
# 18歳以下の		dst: 15	srcs: []
# 天才児を		dst: 16	srcs: [14]
# 集めて		dst: 20	srcs: [15]
# 公然と		dst: 20	srcs: []
# AI兵器の		dst: 19	srcs: []
# 開発に		dst: 20	srcs: [18]
# 投じられてもいる。		dst: 37	srcs: [11, 13, 16, 17, 19]
# マサチューセッツ工科大学		dst: 22	srcs: []
# （MIT）の		dst: 23	srcs: [21]
# 教授やなどに		dst: 24	srcs: [22]
# よれば、		dst: 37	srcs: [23]
# 中国では		dst: 36	srcs: []
# プライバシー意識の		dst: 27	srcs: []
# 強い		dst: 28	srcs: [26]
# 欧米と		dst: 29	srcs: [27]
# 比較して		dst: 36	srcs: [28]
# AIの		dst: 31	srcs: []
# 研究や		dst: 33	srcs: [30]
# 新技術の		dst: 33	srcs: []
# 実験を		dst: 34	srcs: [31, 32]
# しやすい		dst: 35	srcs: [33]
# 環境に		dst: 36	srcs: [34]
# あると		dst: 37	srcs: [25, 29, 35]
# されている。		dst: 48	srcs: [20, 24, 36]
# 日本で		dst: 41	srcs: []
# スーパーコンピュータの		dst: 40	srcs: []
# 研究開発を		dst: 41	srcs: [39]
# 推進している		dst: 42	srcs: [38, 40]
# 齊藤元章も		dst: 46	srcs: [41]
# AIの		dst: 44	srcs: []
# 開発において		dst: 46	srcs: [43]
# 中国が		dst: 46	srcs: []
# リードする		dst: 47	srcs: [42, 44, 45]
# 可能性を		dst: 48	srcs: [46]
# 主張している。		dst: 54	srcs: [37, 47]
# 世界の		dst: 50	srcs: []
# ディープラーニング用計算機の		dst: 51	srcs: [49]
# 4分の3は		dst: 54	srcs: [50]
# 中国が		dst: 53	srcs: []
# 占めてるとも		dst: 54	srcs: [52]
# される。		dst: 88	srcs: [48, 51, 53]
# 米国政府に		dst: 56	srcs: []
# よれば、		dst: 88	srcs: [55]
# 2013年から		dst: 64	srcs: []
# ディープラーニングに関する		dst: 59	srcs: []
# 論文数では		dst: 64	srcs: [58]
# 中国が		dst: 64	srcs: []
# 米国を		dst: 62	srcs: []
# 超えて		dst: 64	srcs: [61]
# 世界一と		dst: 64	srcs: []
# なっている。		dst: 71	srcs: [57, 59, 60, 62, 63]
# やなど		dst: 68	srcs: []
# AIの		dst: 68	srcs: []
# 世界的な		dst: 68	srcs: []
# 大会でも		dst: 71	srcs: [65, 66, 67]
# 中国勢が		dst: 71	srcs: []
# 上位を		dst: 71	srcs: []
# 独占している。		dst: 88	srcs: [64, 68, 69, 70]
# 大手AI企業Google、		dst: 73	srcs: []
# マイクロソフト、		dst: 74	srcs: [72]
# アップルなどの		dst: 75	srcs: [73]
# 幹部でも		dst: 76	srcs: [74]
# あった		dst: 77	srcs: [75]
# 台湾系アメリカ人科学者のは		dst: 88	srcs: [76]
# 中国が		dst: 81	srcs: []
# AIで		dst: 81	srcs: []
# 覇権を		dst: 81	srcs: []
# 握りつつあると		dst: 82	srcs: [78, 79, 80]
# する		dst: 83	srcs: [81]
# 『』を		dst: 84	srcs: [82]
# 著して		dst: 88	srcs: [83]
# アメリカの		dst: 87	srcs: []
# 政界や		dst: 87	srcs: []
# メディアなどが		dst: 88	srcs: [85, 86]
# 取り上げた。		dst: -1	srcs: [54, 56, 71, 77, 84, 87]
#
# フランス大統領エマニュエル・マクロンは		dst: 17	srcs: []
# AI分野の		dst: 2	srcs: []
# 開発支援に		dst: 3	srcs: [1]
# 向け		dst: 7	srcs: [2]
# 5年で		dst: 7	srcs: []
# 15億ドル		dst: 6	srcs: []
# （約1600億円）を		dst: 7	srcs: [5]
# 支出すると		dst: 8	srcs: [3, 4, 6]
# 宣言し、		dst: 11	srcs: [7]
# AI研究所を		dst: 11	srcs: []
# パリに		dst: 11	srcs: []
# 開き、		dst: 17	srcs: [8, 9, 10]
# フェイスブック、		dst: 13	srcs: []
# グーグル、		dst: 14	srcs: [12]
# サムスン、		dst: 15	srcs: [13]
# DeepMind、		dst: 16	srcs: [14]
# 富士通などを		dst: 17	srcs: [15]
# 招致した。		dst: 22	srcs: [0, 11, 16]
# イギリスとも		dst: 21	srcs: []
# AI研究における		dst: 21	srcs: []
# 長期的な		dst: 21	srcs: []
# 連携も		dst: 22	srcs: [18, 19, 20]
# 決定されている。		dst: -1	srcs: [17, 21]
#
# EU全体としても、		dst: 4	srcs: []
# 「Horizon2020」計画を通じて、		dst: 4	srcs: []
# 215億ユーロが		dst: 3	srcs: []
# 投じられる		dst: 4	srcs: [2]
# 方向。		dst: -1	srcs: [0, 1, 3]
#
# 韓国は、		dst: 4	srcs: []
# 20億ドルを		dst: 2	srcs: []
# 2022年までに		dst: 4	srcs: [1]
# 投資を		dst: 4	srcs: []
# する。		dst: 9	srcs: [0, 2, 3]
# 6つの		dst: 6	srcs: []
# AI機関を		dst: 7	srcs: [5]
# 設立し		dst: 9	srcs: [6]
# 褒賞制度も		dst: 9	srcs: []
# 作られた。		dst: 15	srcs: [4, 7, 8]
# 目標は		dst: 14	srcs: []
# 2022年までに		dst: 14	srcs: []
# AIの		dst: 13	srcs: []
# 世界トップ4に		dst: 14	srcs: [12]
# 入ることだと		dst: 15	srcs: [10, 11, 13]
# いう。		dst: -1	srcs: [9, 14]
#
# 日経新聞調べに		dst: 1	srcs: []
# よると、		dst: 9	srcs: [0]
# 国別の		dst: 3	srcs: []
# AI研究論文数は		dst: 7	srcs: [2]
# 1位		dst: 6	srcs: []
# 米国、		dst: 6	srcs: []
# 2位中国、		dst: 7	srcs: [4, 5]
# 3位インドで		dst: 9	srcs: [3, 6]
# 日本は		dst: 9	srcs: []
# 7位だった。		dst: -1	srcs: [1, 7, 8]
#
# プログラミング言語は		dst: 5	srcs: []
# C++の		dst: 2	srcs: []
# ほか		dst: 5	srcs: [1]
# Pythonが		dst: 5	srcs: []
# 広く		dst: 5	srcs: []
# 使われている。		dst: -1	srcs: [0, 2, 3, 4]
#
# 深層学習を		dst: 1	srcs: []
# 利用するには		dst: 2	srcs: [0]
# 微分、		dst: 4	srcs: [1]
# 線形代数、		dst: 4	srcs: []
# 確率・統計といった		dst: 5	srcs: [2, 3]
# 大学レベル以上の		dst: 6	srcs: [4]
# 数学知識が		dst: 8	srcs: [5]
# 必要と		dst: 8	srcs: []
# なる。		dst: -1	srcs: [6, 7]
#
# 脳シミュレーションを		dst: 1	srcs: []
# 行うには		dst: 4	srcs: [0]
# 脳神経科学の		dst: 3	srcs: []
# 知識も		dst: 4	srcs: [2]
# 重要となる。		dst: -1	srcs: [1, 3]
#
# 人工知能学会の		dst: 1	srcs: []
# 松尾豊は、		dst: 17	srcs: [0]
# 著書		dst: 11	srcs: []
# 『人工知能は		dst: 11	srcs: []
# 人間を		dst: 5	srcs: []
# 超えるか』内に		dst: 6	srcs: [4]
# 於いて、		dst: 9	srcs: [5]
# 人間に対して		dst: 9	srcs: []
# 反乱を		dst: 9	srcs: []
# 起こす		dst: 10	srcs: [6, 7, 8]
# 可能性を		dst: 11	srcs: [9]
# 否定しているが、		dst: 17	srcs: [2, 3, 10]
# 人工知能の		dst: 13	srcs: []
# 危険性について、		dst: 17	srcs: [12]
# 警鐘を		dst: 15	srcs: []
# 鳴らしている		dst: 16	srcs: [14]
# 著名人も		dst: 17	srcs: [15]
# いる。		dst: -1	srcs: [1, 11, 13, 16]
#
# MITの		dst: 1	srcs: []
# 教授は		dst: 16	srcs: [0]
# 莫大な		dst: 3	srcs: []
# 資金力と		dst: 5	srcs: [2]
# 人権の		dst: 5	srcs: []
# 弾圧を		dst: 6	srcs: [3, 4]
# 併せ持つ		dst: 7	srcs: [5]
# 中華人民共和国が		dst: 10	srcs: [6]
# 人工知能の		dst: 9	srcs: []
# 開発競争で		dst: 10	srcs: [8]
# 成功すれば		dst: 14	srcs: [7, 9]
# 民主的な		dst: 12	srcs: []
# 国家が		dst: 14	srcs: [11]
# 技術革新に		dst: 14	srcs: []
# 優位という		dst: 15	srcs: [10, 12, 13]
# ...
# 2019年		dst: 165	srcs: []
# 11月に		dst: 185	srcs: [164]
# マーク・エスパー国防長官は		dst: 185	srcs: []
# 中国が		dst: 171	srcs: []
# AIによって		dst: 171	srcs: []
# 新しい		dst: 170	srcs: []
# 監視国家を		dst: 171	srcs: [169]
# 構築しているだけでなく、		dst: 182	srcs: [167, 168, 170]
# 中東で		dst: 177	srcs: []
# 翼竜や		dst: 174	srcs: []
# 彩虹など		dst: 175	srcs: [173]
# 無人攻撃機を		dst: 177	srcs: [174]
# 大量に		dst: 177	srcs: []
# 拡散させて		dst: 180	srcs: [172, 175, 176]
# AIで		dst: 180	srcs: []
# 自律的に		dst: 180	srcs: []
# 攻撃する		dst: 181	srcs: [177, 178, 179]
# ドローン兵器も		dst: 182	srcs: [180]
# 販売している		dst: 183	srcs: [171, 181]
# ことに		dst: 185	srcs: [182]
# 警鐘を		dst: 185	srcs: []
# 鳴らした。		dst: -1	srcs: [163, 165, 166, 183, 184]
#
# ロシアと		dst: 1	srcs: []
# 中国は		dst: 3	srcs: [0]
# 既に		dst: 3	srcs: []
# 実用化してると		dst: 4	srcs: [1, 2]
# される		dst: 5	srcs: [3]
# ハッキングの		dst: 6	srcs: [4]
# 自動化の		dst: 7	srcs: [5]
# 他、		dst: 18	srcs: [6]
# 特定の		dst: 9	srcs: []
# 個人を		dst: 10	srcs: [8]
# 攻撃したり		dst: 12	srcs: [9]
# ディープフェイクで		dst: 12	srcs: []
# なりすましたり、		dst: 15	srcs: [10, 11]
# ボット投稿により		dst: 15	srcs: []
# 世論を		dst: 15	srcs: []
# 操る		dst: 16	srcs: [12, 13, 14]
# 等の		dst: 17	srcs: [15]
# 懸念が		dst: 18	srcs: [16]
# 挙げられている。		dst: -1	srcs: [7, 17]
#
# Googleは		dst: 11	srcs: []
# 2019年		dst: 2	srcs: []
# 3月、		dst: 10	srcs: [1]
# 人工知能プロジェクトを		dst: 5	srcs: []
# 倫理面で		dst: 5	srcs: []
# 指導する		dst: 6	srcs: [3, 4]
# ために		dst: 8	srcs: [5]
# 哲学者・政策立案者・経済学者・テクノロジスト等で		dst: 8	srcs: []
# 構成される、		dst: 10	srcs: [6, 7]
# AI倫理委員会を		dst: 10	srcs: []
# 設置すると		dst: 11	srcs: [2, 8, 9]
# 発表した。		dst: 20	srcs: [0, 10]
# しかし		dst: 20	srcs: []
# 倫理委員会には		dst: 17	srcs: []
# 反科学・反マイノリティ・地球温暖化懐疑論等を		dst: 15	srcs: []
# 支持する		dst: 16	srcs: [14]
# 人物も		dst: 17	srcs: [15]
# 含まれており、		dst: 20	srcs: [13, 16]
# Google社員らは		dst: 20	srcs: []
# 解任を		dst: 20	srcs: []
# 要請した。		dst: 31	srcs: [11, 12, 17, 18, 19]
# 4月4日、		dst: 31	srcs: []
# Googleは		dst: 31	srcs: []
# 倫理委員会が		dst: 31	srcs: []
# 「期待どおりに		dst: 25	srcs: []
# 機能できない		dst: 26	srcs: [24]
# ことが		dst: 27	srcs: [25]
# 判明した」という		dst: 28	srcs: [26]
# 理由で、		dst: 31	srcs: [27]
# 委員会の		dst: 30	srcs: []
# 解散を		dst: 31	srcs: [29]
# 発表した。		dst: -1	srcs: [20, 21, 22, 23, 28, 30]
#
# 東洋哲学を		dst: 2	srcs: []
# AIに		dst: 2	srcs: []
# 吸収させるという		dst: 3	srcs: [0, 1]
# 三宅陽一郎の		dst: 4	srcs: [2]
# テーマに		dst: 5	srcs: [3]
# 応じて、		dst: 21	srcs: [4]
# 井口尊仁は		dst: 10	srcs: []
# 「鳥居（TORII）」という		dst: 8	srcs: []
# 自分の		dst: 9	srcs: [7]
# プロジェクトを		dst: 10	srcs: [8]
# 挙げ、		dst: 21	srcs: [6, 9]
# 「われわれは		dst: 12	srcs: []
# アニミズムで、		dst: 18	srcs: [11]
# あらゆる		dst: 14	srcs: []
# ものに		dst: 16	srcs: [13]
# 霊的存在を		dst: 16	srcs: []
# 見いだす		dst: 17	srcs: [14, 15]
# 文化が		dst: 18	srcs: [16]
# あります」と		dst: 21	srcs: [12, 17]
# 三宅および		dst: 20	srcs: []
# 立石従寛に		dst: 21	srcs: [19]
# 語る。		dst: 35	srcs: [5, 10, 18, 20]
# アニミズム的人工知能論は		dst: 35	srcs: []
# 現代アートや、		dst: 34	srcs: []
# 「禅の		dst: 25	srcs: []
# 悟りを		dst: 27	srcs: [24]
# どう		dst: 27	srcs: []
# やって		dst: 29	srcs: [25, 26]
# AIに		dst: 29	srcs: []
# やらせるか」を		dst: 30	srcs: [27, 28]
# 論じた		dst: 31	srcs: [29]
# 三宅の		dst: 34	srcs: [30]
# 『人工知能の		dst: 33	srcs: []
# ための		dst: 34	srcs: [32]
# 哲学塾東洋哲学篇』にも		dst: 35	srcs: [23, 31, 33]
# 通じている。		dst: -1	srcs: [21, 22, 34]
#
# 元Googleエンジニアの		dst: 1	srcs: []
# アンソニー゠レバンドウスキーは		dst: 61	srcs: [0]
# 2017年、		dst: 61	srcs: []
# AIを		dst: 5	srcs: []
# 神と		dst: 5	srcs: []
# する		dst: 6	srcs: [3, 4]
# 宗教団体		dst: 61	srcs: [5]
# 「WayoftheFuture(未来の		dst: 8	srcs: []
# 道)」を		dst: 9	srcs: [7]
# 創立している。		dst: 61	srcs: [8]
# 団体の		dst: 11	srcs: []
# 使命は		dst: 30	srcs: [10]
# 「人工知能		dst: 13	srcs: []
# （AI）に		dst: 14	srcs: [12]
# 基づいた		dst: 15	srcs: [13]
# Godheadの		dst: 16	srcs: [14]
# 実現を		dst: 17	srcs: [15]
# 促進し		dst: 18	srcs: [16]
# 開発する		dst: 19	srcs: [17]
# こと、そして		dst: 28	srcs: [18]
# Godheadの		dst: 21	srcs: []
# 理解と		dst: 22	srcs: [20]
# 崇拝を通して		dst: 25	srcs: [21]
# 社会を		dst: 25	srcs: []
# より		dst: 25	srcs: []
# 良くする		dst: 26	srcs: [22, 23, 24]
# ことに		dst: 27	srcs: [25]
# 貢献する		dst: 28	srcs: [26]
# こと」と		dst: 30	srcs: [19, 27]
# 抽象的に		dst: 30	srcs: []
# 表現されており、		dst: 36	srcs: [11, 28, 29]
# 多くの		dst: 32	srcs: []
# 海外メディアは		dst: 36	srcs: [31]
# SF映画や		dst: 34	srcs: []
# 歴史などと		dst: 35	srcs: [33]
# 関連付けて		dst: 36	srcs: [34]
# 報道した。		dst: 61	srcs: [30, 32, 35]
# Uberと		dst: 38	srcs: []
# Googleの		dst: 39	srcs: [37]
# Waymoは、		dst: 61	srcs: [38]
# レバンドウスキーが		dst: 43	srcs: []
# 自動運転に関する		dst: 42	srcs: []
# 機密情報を		dst: 43	srcs: [41]
# 盗用した		dst: 44	srcs: [40, 42]
# ことを		dst: 45	srcs: [43]
# 訴え		dst: 47	srcs: [44]
# 裁判を		dst: 47	srcs: []
# 行っている		dst: 48	srcs: [45, 46]
# 一方、		dst: 61	srcs: [47]
# レバンドウスキーは		dst: 61	srcs: []
# Uberの		dst: 51	srcs: []
# 元CEO		dst: 58	srcs: [50]
# （トラビス゠カラニック）に対し		dst: 58	srcs: []
# 「ボット		dst: 54	srcs: []
# ひとつずつ、		dst: 57	srcs: [53]
# 我々は		dst: 57	srcs: []
# 世界を		dst: 57	srcs: []
# 征服するんだ」と		dst: 58	srcs: [54, 55, 56]
# 発言するなど、		dst: 60	srcs: [51, 52, 57]
# 野心的な		dst: 60	srcs: []
# 振る舞いを		dst: 61	srcs: [58, 59]
# 示している。		dst: -1	srcs: [1, 2, 6, 9, 36, 39, 48, 49, 60]
#
# 相愛大学人文学部教授の		dst: 1	srcs: []
# 釈徹宗は		dst: 9	srcs: [0]
# 「哲学や		dst: 3	srcs: []
# 思想や		dst: 4	srcs: [2]
# 文学と、		dst: 6	srcs: [3]
# 宗教や		dst: 6	srcs: []
# 霊性論との		dst: 7	srcs: [4, 5]
# 線引きも		dst: 8	srcs: [6]
# 不明瞭になってきています。」と		dst: 9	srcs: [7]
# 述べている。		dst: 21	srcs: [1, 8]
# 哲学者・倫理学者である		dst: 11	srcs: []
# 内田樹に		dst: 12	srcs: [10]
# よれば、		dst: 21	srcs: [11]
# 「本物の		dst: 14	srcs: []
# 哲学者は		dst: 20	srcs: [13]
# みんな		dst: 20	srcs: []
# 死者と		dst: 17	srcs: []
# 幽霊と		dst: 18	srcs: [16]
# 異界の		dst: 19	srcs: [17]
# 話を		dst: 20	srcs: [18]
# している。」と		dst: 21	srcs: [14, 15, 19]
# いう。		dst: -1	srcs: [9, 12, 20]
#
# 発明家レイ・カーツワイルが		dst: 1	srcs: []
# 言うには、		dst: 12	srcs: [0]
# 哲学者ジョン・サールが		dst: 3	srcs: []
# 提起した		dst: 7	srcs: [2]
# 強い		dst: 7	srcs: []
# AIと		dst: 6	srcs: []
# 弱い		dst: 7	srcs: [5]
# AIの		dst: 8	srcs: [3, 4, 6]
# 論争は、		dst: 12	srcs: [7]
# AIの		dst: 10	srcs: []
# 哲学議論で		dst: 12	srcs: [9]
# ホットな		dst: 12	srcs: []
# 話題である。		dst: 28	srcs: [1, 8, 10, 11]
# 哲学者ジョン・サールおよび		dst: 14	srcs: []
# ダニエル・デネットに		dst: 15	srcs: [13]
# よると、		dst: 28	srcs: [14]
# サールの		dst: 18	srcs: []
# 「中国語の		dst: 18	srcs: []
# 部屋」や		dst: 20	srcs: [16, 17]
# ネド・ブロックらの		dst: 20	srcs: []
# 「中国脳」といった		dst: 21	srcs: [18, 19]
# 機能主義に		dst: 22	srcs: [20]
# 批判的な		dst: 23	srcs: [21]
# 思考実験は、		dst: 28	srcs: [22]
# 真の		dst: 25	srcs: []
# 意識が		dst: 27	srcs: [24]
# 形式論理システムによって		dst: 27	srcs: []
# 実現できないと		dst: 28	srcs: [25, 26]
# 主張している。		dst: -1	srcs: [12, 15, 23, 27]
#
# 『科学を		dst: 1	srcs: []
# 語るとは		dst: 3	srcs: [0]
# どういう		dst: 3	srcs: []
# ことか』において		dst: 67	srcs: [1, 2]
# 科学者の		dst: 5	srcs: []
# 須藤靖は、		dst: 67	srcs: [4]
# 科学についての		dst: 7	srcs: []
# 哲学的考察		dst: 8	srcs: [6]
# （科学哲学）が、		dst: 13	srcs: [7]
# 実際には		dst: 13	srcs: []
# 科学と		dst: 11	srcs: []
# 「断絶」している		dst: 12	srcs: [10]
# ことを		dst: 13	srcs: [11]
# 指摘している。		dst: 67	srcs: [8, 9, 12]
# また、		dst: 67	srcs: []
# 「心」や		dst: 16	srcs: []
# 「意識」という		dst: 17	srcs: [15]
# 問題を		dst: 18	srcs: [16]
# 解明してきた		dst: 19	srcs: [17]
# 脳科学・計算機科学		dst: 20	srcs: [18]
# （コンピュータ科学）・人工知能研究開発等に		dst: 21	srcs: [19]
# 関連して、		dst: 31	srcs: [20]
# 科学者の		dst: 23	srcs: []
# フランシス・クリックは		dst: 31	srcs: [22]
# 「哲学者たちは		dst: 25	srcs: []
# 2000年という		dst: 26	srcs: [24]
# 長い間、		dst: 30	srcs: [25]
# ほとんど		dst: 30	srcs: []
# 何も		dst: 30	srcs: []
# 成果を		dst: 30	srcs: []
# 残してこなかった」と		dst: 31	srcs: [26, 27, 28, 29]
# 批判している。		dst: 39	srcs: [21, 23, 30]
# こうした		dst: 33	srcs: []
# 観点において、		dst: 39	srcs: [32]
# 哲学は		dst: 38	srcs: []
# 「二流どころか		dst: 36	srcs: []
# 三流」の		dst: 37	srcs: [35]
# 学問・科学に		dst: 38	srcs: [36]
# 過ぎない、と		dst: 39	srcs: [34, 37]
# 評価されている。		dst: 67	srcs: [31, 33, 38]
# 脳科学者の		dst: 41	srcs: []
# 澤口俊之は、		dst: 67	srcs: [40]
# クリックに		dst: 43	srcs: []
# 賛同し		dst: 54	srcs: [42]
# 「これは		dst: 48	srcs: []
# 私の		dst: 46	srcs: []
# ため息まじりの		dst: 47	srcs: [45]
# 愚痴に		dst: 48	srcs: [46]
# なるが、		dst: 53	srcs: [44, 47]
# 哲学者や		dst: 50	srcs: []
# 思想家というのは		dst: 53	srcs: [49]
# つくづく		dst: 53	srcs: []
# 『暇』だと		dst: 53	srcs: []
# 思う」と		dst: 54	srcs: [48, 50, 51, 52]
# 述べている。		dst: 67	srcs: [43, 53]
# 実際、		dst: 67	srcs: []
# 哲学は		dst: 59	srcs: []
# 暇		dst: 58	srcs: []
# （スコレー）から		dst: 59	srcs: [57]
# 始まったと		dst: 61	srcs: [56, 58]
# アリストテレスが		dst: 61	srcs: []
# 伝えており、		dst: 67	srcs: [59, 60]
# 上記のような		dst: 63	srcs: []
# 否定的発言も		dst: 64	srcs: [62]
# 的外れではないと、		dst: 67	srcs: [63]
# 科学哲学者の		dst: 66	srcs: []
# 野家啓一は		dst: 67	srcs: [65]
# 言う。		dst: -1	srcs: [3, 5, 13, 14, 39, 41, 54, 55, 61, 64, 66]
#
# 哲学者は、		dst: 6	srcs: []
# 科学とは		dst: 2	srcs: []
# 違う		dst: 3	srcs: [1]
# 日常的言語で		dst: 6	srcs: [2]
# 「存在」や		dst: 5	srcs: []
# 「宇宙」を		dst: 6	srcs: [4]
# 語ろうとしてきた。		dst: 11	srcs: [0, 3, 5]
# しかし		dst: 11	srcs: []
# 理論物理学者ディラックは、		dst: 11	srcs: []
# 哲学者を		dst: 11	srcs: []
# ことさら		dst: 11	srcs: []
# 信用していなかった。		dst: 34	srcs: [6, 7, 8, 9, 10]
# ディラックが		dst: 13	srcs: []
# 見た		dst: 14	srcs: [12]
# ところ、		dst: 34	srcs: [13]
# ウィトゲンシュタインを		dst: 16	srcs: []
# 含め		dst: 18	srcs: [15]
# 哲学者たちは		dst: 18	srcs: []
# 量子力学どころか、		dst: 22	srcs: [16, 17]
# パスカル以降の		dst: 20	srcs: []
# 「確率」の		dst: 21	srcs: [19]
# 概念さえ		dst: 22	srcs: [20]
# 理解していない。		dst: 34	srcs: [18, 21]
# 非科学的な		dst: 24	srcs: []
# 日常的言語を		dst: 26	srcs: [23]
# いくら		dst: 26	srcs: []
# 使っても、		dst: 31	srcs: [24, 25]
# 正確な		dst: 28	srcs: []
# 意思疎通を		dst: 29	srcs: [27]
# 行う		dst: 30	srcs: [28]
# ことは		dst: 31	srcs: [29]
# できないというのが、		dst: 33	srcs: [26, 30]
# ディラックの		dst: 33	srcs: []
# 考えだと		dst: 34	srcs: [31, 32]
# されている。		dst: -1	srcs: [11, 14, 22, 33]
#
# 生命情報科学者・神経科学者の		dst: 1	srcs: []
# 合原一幸編著		dst: 4	srcs: [0]
# 『人工知能は		dst: 4	srcs: []
# こうして		dst: 4	srcs: []
# 創られる』に		dst: 5	srcs: [1, 2, 3]
# よれば、		dst: 19	srcs: [4]
# AIの		dst: 8	srcs: []
# 急激な		dst: 8	srcs: []
# 発展に		dst: 9	srcs: [6, 7]
# 伴って		dst: 15	srcs: [8]
# 「技術的特異点、		dst: 11	srcs: []
# シンギュラリティ」の		dst: 13	srcs: [10]
# 思想や		dst: 13	srcs: []
# 哲学が		dst: 15	srcs: [11, 12]
# 一部で		dst: 15	srcs: []
# 論じられているが、		dst: 19	srcs: [9, 13, 14]
# 特異点と		dst: 17	srcs: []
# 言っても		dst: 19	srcs: [16]
# 「数学」的な		dst: 19	srcs: []
# 話ではない。		dst: 31	srcs: [5, 15, 17, 18]
# 前掲書は		dst: 31	srcs: []
# 「そもそも		dst: 30	srcs: []
# シンギュラリティと		dst: 23	srcs: []
# 関係した		dst: 24	srcs: [22]
# 議論における		dst: 27	srcs: [23]
# 『人間の		dst: 26	srcs: []
# 脳を		dst: 27	srcs: [25]
# 超える』という		dst: 28	srcs: [24, 26]
# 言明自体が		dst: 30	srcs: [27]
# うまく		dst: 30	srcs: []
# 定義できていない」と		dst: 31	srcs: [21, 28, 29]
# 記している。		dst: 39	srcs: [19, 20, 30]
# 確かに、		dst: 39	srcs: []
# 脳を		dst: 35	srcs: []
# 「デジタル情報処理システム」として		dst: 35	srcs: []
# 捉える		dst: 36	srcs: [33, 34]
# 観点から		dst: 37	srcs: [35]
# 見れば、		dst: 39	srcs: [36]
# シンギュラリティは		dst: 39	srcs: []
# 起こり得るかもしれない。		dst: 75	srcs: [31, 32, 37, 38]
# しかし		dst: 75	srcs: []
# 実際の		dst: 42	srcs: []
# 脳は		dst: 75	srcs: [41]
# そのような		dst: 45	srcs: []
# 単純な		dst: 45	srcs: []
# システムではなく、		dst: 49	srcs: [43, 44]
# デジタルと		dst: 47	srcs: []
# アナログが		dst: 48	srcs: [46]
# 融合した		dst: 49	srcs: [47]
# 「ハイブリッド系」である		dst: 50	srcs: [45, 48]
# ことが、		dst: 53	srcs: [49]
# 脳神経科学の		dst: 52	srcs: []
# 観察結果で		dst: 53	srcs: [51]
# 示されている。		dst: 75	srcs: [50, 52]
# 前掲書に		dst: 55	srcs: []
# よると、		dst: 75	srcs: [54]
# 神経膜では		dst: 59	srcs: []
# 様々な		dst: 58	srcs: []
# 「ノイズ」が		dst: 59	srcs: [57]
# 存在し、		dst: 66	srcs: [56, 58]
# この		dst: 61	srcs: []
# ノイズ付きの		dst: 62	srcs: [60]
# アナログ量によって		dst: 66	srcs: [61]
# 脳内の		dst: 64	srcs: []
# ニューロンの		dst: 65	srcs: [63]
# 「カオス」が		dst: 66	srcs: [64]
# 生み出されている		dst: 67	srcs: [59, 62, 65]
# ため、		dst: 75	srcs: [66]
# このような		dst: 69	srcs: []
# 状況を		dst: 71	srcs: [68]
# デジタルで		dst: 71	srcs: []
# 記述する		dst: 72	srcs: [69, 70]
# ことは		dst: 74	srcs: [71]
# 「極めて		dst: 74	srcs: []
# 困難」と		dst: 75	srcs: [72, 73]
# 考えられている。		dst: -1	srcs: [39, 40, 42, 53, 55, 67, 74]
#
# 数学者の		dst: 1	srcs: []
# 田中一之は		dst: 6	srcs: [0]
# 「一般の		dst: 3	srcs: []
# 哲学者は、		dst: 5	srcs: [2]
# 論理の		dst: 5	srcs: []
# 専門家ではない」と		dst: 6	srcs: [3, 4]
# 述べており、		dst: 18	srcs: [1, 5]
# 計算機科学者		dst: 8	srcs: []
# （コンピュータ科学者）・電子工学者の		dst: 9	srcs: [7]
# トルケル゠フランセーンは、		dst: 18	srcs: [8]
# 哲学者たちによる		dst: 12	srcs: []
# 数学的な		dst: 12	srcs: []
# 言及の		dst: 13	srcs: [10, 11]
# 多くが		dst: 18	srcs: [12]
# 「ひどい		dst: 16	srcs: []
# 誤解や		dst: 16	srcs: []
# 自由連想に		dst: 17	srcs: [14, 15]
# 基づいている」と		dst: 18	srcs: [16]
# 批判している。		dst: 34	srcs: [6, 9, 13, 17]
# 田中に		dst: 20	srcs: []
# よると、		dst: 34	srcs: [19]
# ゲーデルの		dst: 22	srcs: []
# 不完全性定理について		dst: 24	srcs: [21]
# 哲学者が		dst: 24	srcs: []
# 書いた		dst: 25	srcs: [22, 23]
# 本が、		dst: 30	srcs: [24]
# フランセーンの		dst: 27	srcs: []
# 本と		dst: 28	srcs: [26]
# 同じ		dst: 29	srcs: [27]
# 頃に		dst: 30	srcs: [28]
# 書店販売されていたが、		dst: 34	srcs: [25, 29]
# 哲学者の		dst: 32	srcs: []
# 本は		dst: 34	srcs: [31]
# 専門誌によって		dst: 34	srcs: []
# 酷評された。		dst: 49	srcs: [18, 20, 30, 32, 33]
# その		dst: 36	srcs: []
# 本は		dst: 41	srcs: [35]
# 全体として		dst: 41	srcs: []
# 読みやすく		dst: 41	srcs: []
# 一般読者からの		dst: 40	srcs: []
# 評判は		dst: 41	srcs: [39]
# 高かったが、		dst: 49	srcs: [36, 37, 38, 40]
# ゲーデルの		dst: 43	srcs: []
# 証明の		dst: 44	srcs: [42]
# 核		dst: 45	srcs: [43]
# （不動点定理）について、		dst: 49	srcs: [44]
# 根本的な		dst: 47	srcs: []
# 勘違いを		dst: 48	srcs: [46]
# したまま		dst: 49	srcs: [47]
# 説明していた。		dst: 54	srcs: [34, 41, 45, 48]
# 同様の		dst: 51	srcs: []
# 間違いは		dst: 54	srcs: [50]
# 他の		dst: 53	srcs: []
# 入門書などにも		dst: 54	srcs: [52]
# 見られる。		dst: 78	srcs: [49, 51, 53]
# フランセーンに		dst: 56	srcs: []
# よれば、		dst: 78	srcs: [55]
# 不完全性定理に関する		dst: 58	srcs: []
# 誤解・誤用は		dst: 62	srcs: [57]
# 哲学を		dst: 60	srcs: []
# はじめ		dst: 62	srcs: [59]
# 一般に		dst: 62	srcs: []
# 起こっており、		dst: 65	srcs: [58, 60, 61]
# 宗教や		dst: 64	srcs: []
# 神学でも		dst: 65	srcs: [63]
# 乱用されている。		dst: 78	srcs: [62, 64]
# 1931年に		dst: 68	srcs: []
# ゲーデルが		dst: 68	srcs: []
# 示したのは、		dst: 78	srcs: [66, 67]
# 「特定の		dst: 70	srcs: []
# 形式体系formula_1において		dst: 74	srcs: [69]
# 決定		dst: 72	srcs: []
# 不能な		dst: 73	srcs: [71]
# 命題の		dst: 74	srcs: [72]
# 存在」であり、		dst: 78	srcs: [70, 73]
# 一般的な		dst: 76	srcs: []
# 意味での		dst: 77	srcs: [75]
# 「不完全性」についての		dst: 78	srcs: [76]
# 定理ではない。		dst: -1	srcs: [54, 56, 65, 68, 74, 77]
#
# 科学と		dst: 1	srcs: []
# 哲学		dst: -1	srcs: [0]
#
# 『科学を		dst: 1	srcs: []
# 語るとは		dst: 3	srcs: [0]
# どういう		dst: 3	srcs: []
# ことか』に		dst: 4	srcs: [1, 2]
# よると、		dst: 16	srcs: [3]
# 学問の		dst: 6	srcs: []
# 扱う		dst: 7	srcs: [5]
# 問題が		dst: 8	srcs: [6]
# 整理され		dst: 9	srcs: [7]
# 分化した		dst: 10	srcs: [8]
# ことで、		dst: 16	srcs: [9]
# 科学と		dst: 12	srcs: []
# 哲学も		dst: 14	srcs: [11]
# それぞれ		dst: 14	srcs: []
# 異なる		dst: 15	srcs: [12, 13]
# 問題を		dst: 16	srcs: [14]
# 研究するようになった。		dst: 58	srcs: [4, 10, 15]
# これは		dst: 58	srcs: []
# 「研究分野の		dst: 19	srcs: []
# 細分化そのもの」であり、		dst: 24	srcs: [18]
# 「立派な		dst: 21	srcs: []
# 進歩」だと		dst: 24	srcs: [20]
# 宇宙物理学者の		dst: 23	srcs: []
# 須藤は		dst: 24	srcs: [22]
# 言う。		dst: 58	srcs: [19, 21, 23]
# 一方で、		dst: 58	srcs: []
# 科学哲学者・倫理学者の		dst: 27	srcs: []
# 伊勢田哲治は、		dst: 58	srcs: [26]
# 様々な		dst: 29	srcs: []
# 要素を		dst: 30	srcs: [28]
# 含んだ		dst: 31	srcs: [29]
# 「大きな」問題を		dst: 33	srcs: [30]
# 哲学的・統一的に		dst: 33	srcs: []
# 扱う、		dst: 35	srcs: [31, 32]
# かつての		dst: 35	srcs: []
# 天文学について		dst: 36	srcs: [33, 34]
# 言及した。		dst: 55	srcs: [35]
# 「その後の		dst: 38	srcs: []
# 天文学では		dst: 41	srcs: [37]
# その		dst: 40	srcs: []
# 〔哲学的〕問題を		dst: 41	srcs: [39]
# 扱わなくなりましたし、		dst: 46	srcs: [38, 40]
# 今の		dst: 43	srcs: []
# 物理学でも		dst: 46	srcs: [42]
# そういう		dst: 45	srcs: []
# 問題を		dst: 46	srcs: [44]
# 扱わない」と		dst: 47	srcs: [41, 43, 45]
# 述べた		dst: 48	srcs: [46]
# 伊勢田に対し、		dst: 55	srcs: [47]
# 須藤は		dst: 55	srcs: []
# 「その通りですが、		dst: 54	srcs: []
# それ自体に		dst: 54	srcs: []
# 何か		dst: 54	srcs: []
# 問題が		dst: 54	srcs: []
# あるのでしょうか」と		dst: 55	srcs: [50, 51, 52, 53]
# 返している。		dst: 58	srcs: [36, 48, 49, 54]
# 須藤は		dst: 58	srcs: []
# 次のようにも		dst: 58	srcs: []
# 述べた。		dst: -1	srcs: [16, 17, 24, 25, 27, 55, 56, 57]
#
# 須藤は、		dst: 24	srcs: []
# 哲学的に		dst: 2	srcs: []
# 論じられている		dst: 3	srcs: [1]
# 「原因」という		dst: 4	srcs: [2]
# 言葉を		dst: 5	srcs: [3]
# 取り上げて、		dst: 14	srcs: [4]
# 「原因という		dst: 7	srcs: []
# 言葉を		dst: 9	srcs: [6]
# 具体的に		dst: 9	srcs: []
# 定義しない		dst: 10	srcs: [7, 8]
# 限り		dst: 13	srcs: [9]
# それ以上の		dst: 12	srcs: []
# 議論は		dst: 13	srcs: [11]
# 不可能です」と		dst: 14	srcs: [10, 12]
# 述べており、		dst: 24	srcs: [5, 13]
# 「哲学者が		dst: 17	srcs: []
# 興味を		dst: 17	srcs: []
# 持っている		dst: 18	srcs: [15, 16]
# 因果の		dst: 19	srcs: [17]
# 定義が		dst: 21	srcs: [18]
# 物理学者とは		dst: 21	srcs: []
# 違う		dst: 22	srcs: [19, 20]
# ことは		dst: 23	srcs: [21]
# 確かでしょう」と		dst: 24	srcs: [22]
# している。		dst: 34	srcs: [0, 14, 23]
# 伊勢田は、		dst: 34	srcs: []
# 「思った		dst: 27	srcs: []
# 以上に		dst: 32	srcs: [26]
# 物理学者と		dst: 29	srcs: []
# 哲学者の		dst: 30	srcs: [28]
# ものの		dst: 31	srcs: [29]
# 見え方の		dst: 32	srcs: [30]
# 違いというのは		dst: 33	srcs: [27, 31]
# 大きいのかもしれません」と		dst: 34	srcs: [32]
# 述べている。		dst: -1	srcs: [24, 25, 33]
#
# 対談で		dst: 20	srcs: []
# 須藤は		dst: 16	srcs: []
# 「これまで		dst: 6	srcs: []
# けっこう		dst: 6	srcs: []
# 長時間		dst: 6	srcs: []
# 議論を		dst: 6	srcs: []
# 行ってきました。		dst: 15	srcs: [2, 3, 4, 5]
# おかげで、		dst: 10	srcs: []
# 意見の		dst: 9	srcs: []
# 違いは		dst: 10	srcs: [8]
# 明らかになったとは		dst: 11	srcs: [7, 9]
# 思いますが、		dst: 15	srcs: [10]
# 果たして		dst: 15	srcs: []
# 何か		dst: 15	srcs: []
# 決着が		dst: 15	srcs: []
# つくのでしょうか？」と		dst: 16	srcs: [6, 11, 12, 13, 14]
# 発言し、		dst: 20	srcs: [1, 15]
# 伊勢田は		dst: 20	srcs: []
# 「決着は		dst: 19	srcs: []
# つかないでしょうね」と		dst: 20	srcs: [18]
# 答えている。		dst: -1	srcs: [0, 16, 17, 19]
